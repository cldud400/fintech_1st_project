# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import MySQLdb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests
from bs4 import BeautifulSoup

import re

# %%
# matplotlib 한글화

import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus'] = False

path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

# %%
df = pd.read_csv('한국소비자원 생필품 및 서비스 가격 정보_20220128.csv', encoding='ansi')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9180/4014120242.py in <module>
# ----> 1 df = pd.read_csv('한국소비자원 생필품 및 서비스 가격 정보_20220128.csv', encoding='ansi')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '한국소비자원 생필품 및 서비스 가격 정보_20220128.csv'

# %%
df.head()
# Out:
#              상품명         조사일  판매가격       판매업소   제조사 세일여부 원플러스원
# 0  머거본 꿀땅콩(135g)  2022-01-14  3600     CU(본사)   머거본    N     N
# 1  머거본 꿀땅콩(135g)  2022-01-14  2190    롯데슈퍼안양점   머거본    N     N
# 2  허니버터아몬드(210g)  2022-01-14  5990  롯데슈퍼김포전원점  길림양행    N     N
# 3  허니버터아몬드(210g)  2022-01-14  5990    롯데슈퍼길동점  길림양행    N     N
# 4  허니버터아몬드(210g)  2022-01-14  5990    롯데슈퍼구평점  길림양행    N     N

# %%
df[df['상품명'] == '허니버터아몬드(210g)'].groupby(['판매가격','판매업소']).min()
# Out:
#                             상품명         조사일   제조사 세일여부 원플러스원
# 판매가격 판매업소
# 3990 롯데슈퍼남가좌점     허니버터아몬드(210g)  2022-01-28  길림양행    N     N
#      롯데슈퍼대구각산점    허니버터아몬드(210g)  2022-01-14  길림양행    N     N
# 4950 롯데슈퍼상계7동점    허니버터아몬드(210g)  2022-01-14  길림양행    N     N
#      롯데슈퍼프리미엄서초점  허니버터아몬드(210g)  2022-01-14  길림양행    N     N
# 4990 롯데슈퍼상남점      허니버터아몬드(210g)  2022-01-14  길림양행    N     N
# ...                         ...         ...   ...  ...   ...
# 7480 이마트해운대점      허니버터아몬드(210g)  2022-01-14  길림양행  NaN   NaN
#      이마트화성봉담점     허니버터아몬드(210g)  2022-01-14  길림양행  NaN   NaN
#      이마트화정점       허니버터아몬드(210g)  2022-01-14  길림양행  NaN   NaN
#      이마트흥덕점       허니버터아몬드(210g)  2022-01-14  길림양행  NaN   NaN
# 8900 신세계백화점강남점    허니버터아몬드(210g)  2022-01-28  길림양행  NaN   NaN
#
# [597 rows x 5 columns]

# %%
df = pd.read_csv('한국소비자원 생필품 및 서비스 가격 정보_20220128.csv', encoding='cp949')

# %%
# date타임으로 변경 후 년, 월만 남기기
# df.rename(columns={'조사일':'년/월'})
df['조사일'] = df['조사일'].apply(lambda x : x[:7])
df['조사일'] = pd.to_datetime(df['조사일'])

# %%
# 제조사, 세일여부, 원플러스원 drop
# df.drop(['제조사', '세일여부', '원플러스원'], axis = 1, inplace = True)

# %%
# unique한 상품 리스트
prod_ = df['상품명'].unique()
for pro in prod_:
    print(pro)

# %%
# 용량만 분리해서 따로 칼럼으로 만들기
# 일단 보류
# Out:
# array(['머거본 꿀땅콩(135g)', '허니버터아몬드(210g)', '백설 소면(900g)', '옛날국수 소면(900g)',
#        '고향만두(1.08kg)', '비비고 왕교자(1.05kg)', '생야채돼지고기물만두(800g)',
#        '백설 자른 햇당면(300g)', '옛날 자른당면(300g)', '국산콩두부 부침용(380g)',
#        '국산콩두부 찌개용(380g)', '행복한콩 부침두부(300g)', '행복한콩 찌개두부(300g)',
#        '삼양라면(5개입)', '신라면(5개입)', '진라면 순한맛(5개입)', '곰표 밀가루 중력다목적용(1kg)',
#        '백설 찰밀가루(1kg)', '백설 5가지 재료 부침가루(1kg)', '오뚜기 부침가루(1kg)',
#        '삼립호떡 미니꿀호떡(16개입)', '정통크림빵(3개입)', '보노 콘스프(3개입)',
#        '보노 포르치니버섯스프(3개입)', '오뚜기 크림스프(80g)', '스페셜K 오리지널(480g)',
#        '켈로그 콘푸로스트(600g)', '포스트 콘푸라이트(600g)', '오뚜기 간편 미역국(5개입)',
#        '오뚜기 간편 북엇국(5개입)', '3분 쇠고기짜장(200g)', '3분 쇠고기카레(200g)',
#        '오뚜기 3분 백세카레 약간 매운맛(200g)', '청정원 카레여왕 비프카레(160g)', '오뚜기밥(210g)',
#        '오뚜기밥(3개입)', '오뚜기밥(6개입) ', '햇반(210g)', '햇반(3개입)', '햇반(6개입)',
#        '동원 양반 쇠고기죽(287.5g)', '동원 양반 전복죽(287.5g)', '비비고 소고기죽(280g)',
#        '비비고 전복죽(280g)', '농심 신라면 큰사발면(114g)', '오뚜기 참깨라면 컵(110g)',
#        '팔도 왕뚜껑(110g)', '오뚜기 맛있는 쇠고기미역국밥(162g)', '오뚜기 컵밥 제육덮밥(310g)',
#        '햇반 컵반 고추장 제육덮밥(250g)', '햇반 컵반 미역국밥(167g)', '비비고 사골곰탕(500g)',
#        '비비고 육개장(500g)', '오뚜기 옛날 사골곰탕(350g)', '오뚜기 옛날 육개장(300g)',
#        '오리온 포카칩 오리지널(66g)', '포테토칩 오리지날(125g)', '롯데 자일리톨 오리지날(97g)',
#        '빙그레 참붕어 싸만코(150ml)', '아이비(270g)', '참크래커(280g)', '돼지바(70ml)',
#        '메로나(75ml)', '해태 바밤바(63ml)', '롯데 목캔디 허브민트(217g)',
#        '오리온 통아몬드 캔디(90g)', '농심 새우깡(90g)', '롯데 월드콘 바닐라(160ml)',
#        '투게더 오리지널 바닐라(900ml)', '해태 부라보콘 화이트바닐라(140ml)', '닥터유 에너지바(40g)',
#        '닥터유 에너지바(4개입)', '켈로그 레드베리 에너지바(4개입)', '자유시간(36g)', '자유시간(5개입)',
#        '핫브레이크 미니(714g)', '몽쉘 크림(384g)', '오리온 초코파이(18개입)',
#        '롯데 ABC 초코(187g)', '롯데 빅가나 마일드(110g)', '들기름 재래 도시락김(12팩)',
#        '양반 들기름이 그윽한 김(16팩)', '대림 게맛살 큰잔치(300g)', '동원 싱싱맛살 실속(500g)',
#        '삼호 안심 김밥맛살(264g)', '삼호 안심 부산어묵(400g)', '동원참치 라이트스탠다드(150g)',
#        '동원참치 라이트스탠다드(4캔)', '마일드참치(150g)', '마일드참치(3개)',
#        '사조참치 살코기 안심따개(4캔)', '양조간장 501(500ml)', '진간장 금F3(930ml)',
#        '순창 오리지널 우리쌀 찰고추장(1kg)', '해찬들 우리쌀태양초골드(1kg)',
#        '해표 순창궁 태양초 100% 우리햅쌀 고추장(1.8kg)', '동서 아카시아꿀(600g)', '동서벌꿀(600g)',
#        '샘표 시골집 토장(900g)', '순창 재래식안심생된장(1kg)', '해찬들 재래식 된장(1kg)',
#        '청정원 발사믹 드레싱', '청정원 오리엔탈 드레싱', '오뚜기 고소한 골드 마요네즈(500g)',
#        '청정원 고소한 마요네즈(500g)', '백설 자일로스 설탕(1kg)', '백설 하얀설탕(1kg)',
#        '큐원 하얀설탕(1kg)', '백설 구운소금(500g)', '청정원 미원 맛소금(500g)', '해표 꽃소금(1kg)',
#        '백설 식용유(1.5L)', '오뚜기 콩기름 100%(900ml)', '해표 맑고 신선한 식용유(900ml)',
#        '백설 건강발효 사과식초(800ml)', '백설 건강발효 현미식초(800ml)', '오뚜기 사과식초(900ml)',
#        '청정원 순창 양념듬뿍 쌈장(500g)', '해찬들 사계절 쌈장(500g)', '해표 순창궁 양념쌈장(500g)',
#        '딸기잼(500g)', '복음자리 딸기잼(370g)', '백설 진한참기름', '오뚜기 참기름(320ml)',
#        '오뚜기카레 순한맛(100g)', '청정원 카레여왕 구운마늘&amp;양파(108g)',
#        '오뚜기 토마토 케찹(500g)', '청정원 진한 토마토 케찹(500g)', '산들애 국내산 해물(250g)',
#        '청정원 맛선생 국내산해물(250g)', '달콤한 베지밀 비(16팩)', '달콤한 삼육두유 B',
#        '매일두유 담백한 맛(16팩)', '국순당 생막걸리(750ml)', '국순당 우국생(750ml)',
#        '서울장수생막걸리(750ml)', '제주 위트 에일(500ml)', '카스 프레쉬(500ml)',
#        '카스 프레쉬(6캔)', '테라(500ml)', '하이트 엑스트라 콜드(500ml)', '하이트 엑스트라 콜드(6캔)',
#        '비타500(10개입)', '오로나민C(10개입)', '스프라이트(1.5L)', '칠성사이다 제로(1.5L)',
#        '삼다수(2L)', '삼다수(500ml)', '아이시스(2L)', '아이시스(500ml)', '삼다수(2L*6개)',
#        '삼다수(500ml*20개)', '참이슬 클래식(360ml)', '참이슬 후레쉬(360ml)',
#        '처음처럼(360ml)', '레드불 에너지 드링크(250ml)', '롯데 핫식스(250ml)',
#        '몬스터 에너지(355ml)', '게토레이 레몬(600ml)', '파워에이드 마운틴블라스트(520ml)',
#        '포카리스웨트(620ml)', '델몬트 오렌지 100(1.5L)', '미넷메이드 오렌지(1.5L)',
#        '남양 17차 티백(80개입)', '동서현미녹차(100개입)', '맥심 티오피 마스터 라떼(275ml)',
#        '바리스타룰스 콜드브루 블랙(325ml)', '아카페라 아메리카노(240ml)',
#        '맥스웰 하우스 오리지날(180개입)', '맥심 모카골드 마일드(200개입)',
#        '카누 마일드 로스트 아메리카노(30개입)', '프렌치카페 카페믹스(220개입)', '코카콜라(1.8L)',
#        '펩시콜라(1.8L)', '마주앙 레드(750ml)', '진로 와인(500ml)', '오뚜기 콘마가린(180g)',
#        '떠먹는 불가리스 딸기(4개)', '바이오 플레인 요거트(4개)', '불가리스(4개)', '요플레 오리지널(4개)',
#        '이오(5개)', '앱솔루트 명작 3단계(800g)', '임페리얼 드림 XO 3단계(800g)',
#        '프리미엄 산양분유 1단계(800g)', '그릴후랑크(600g)', '백설 그릴 비엔나(720g)',
#        '의성마늘 빅그릴 비엔나(600g)', '주부9단 프랑크소시지(900g)', '남양유업 맛있는우유GT(1L)',
#        '매일우유 오리지널(900ml)', '서울우유 흰우유(1L)', '파스퇴르우유 후레쉬(930ml)',
#        '드빈치 고칼슘치즈(15매)', '매일유업 뼈로가는 칼슘치즈(270g)', '서울우유 체다슬라이스치즈(400g)',
#        '체다치즈(15매)', '스팸 클래식(200g)', '의성마늘 한입슬라이스햄(60g)',
#        '주부9단 슬라이스햄(300g)', '마미손 고무장갑 중(2세트)', '크린랩 고무장갑 중(2세트)',
#        '크린랩(22cm x 50m)', '크린랩(30cm x 50m)', '맥스 부탄가스(4개)', '썬 부탄가스(4개)',
#        '무균무때 세정제 욕실용(900ml)', '유한락스 레귤러(1.8L)', '유한락스 욕실청소용(1800ml)',
#        '유한락스 후레쉬(1.5L)', '홈스타 락스와세제 후로랄파인(750ml)', '홈스타 욕실용 세정제(900ml)',
#        '에프킬라 에어로졸 무향(500ml)', '컴배트 스피드 에어졸(500ml)', '홈키파 수성 에어졸(500ml)',
#        '다우니 고농축 섬유유연제 엑스퍼트(2L)', '샤프란 아우라 초고농축 섬유유연제 홀리데이판타지(2.3L)',
#        '피죤 섬유유연제 핑크로즈(2.1L)', '샤프란 네이처 섬유탈취제 프레쉬 민트(300ml)',
#        '페브리즈 상쾌한향(370ml)', '페브리즈 상쾌한향(900ml)', '때가 쏙 비트 분말세제(6kg)',
#        '비트 트리플 액션(2.8L)', '스파크 분말세제(6kg)', '테크 UP 분말세제(4kg)',
#        '테크 베이킹소다 액체세제(3L)', '퍼실 파워젤 액체 드럼용(2.7L)', '퍼실 파워젤 액체 일반용(2.7L)',
#        '물먹는하마(3개입)', '피죤 습기제로(8개입)',
#        '3M 후레쉬 슬라이드 지퍼백 중형(21cm x 16cm x 6cm)', '손잡이 크린백(35cm x 45cm)',
#        '지퍼락 지퍼백 냉장 중형(20매)', '크린롤백(25cm x 35cm)', '크린지퍼백(18cm x 20cm)',
#        '메소드 주방세제 핑크(532ml)', '자연퐁 솔잎(490ml)',
#        '프릴 시크릿 오브 베이킹소다 퓨어레몬향(750ml)', '항균 트리오(973ml)', '코디 키친타월(6롤)',
#        '크리넥스 안심 키친타월(6롤)', '밥이보약 CAT 걱정없는 헤어볼', '밥이보약 튼튼한관절',
#        'JB 뉴 베드타임 로션(500ml)', '정말 순한 바디밀크(450ml)', '크리넥스 KF94 4단 마스크',
#        'PACE6 스타일 면도날(4개)', '플로쉴드 옐로우 면도날(4개)', '하이드로8 면도날(8개)',
#        '도브 뷰티 너리싱 바디워시(1kg)', '도브 센스티브 스킨 바디워시(1kg)',
#        '세이 온더바디 고보습 아이리스(900ml)', '오가니스트 히말라야 핑크솔트 바디워시 리프레싱 민트향(865ml)',
#        '해피바스 라벤더 에센스 바디워시(900g)', '도브 뷰티바(4개)', '드봉 스위트로즈(4개)',
#        '해피바스 허브 라벤더 아로마 바(4개)', '쏘피 바디피트 볼록맞춤 날개 중형(32개입)',
#        '좋은느낌 울트라슬림 에어핏쿠션 날개 중형(36개입)', '좋은느낌 좋은순면 울트라 날개 중형(36개입)',
#        '화이트 시크릿홀 날개 중형(36개입)', '려 함빛 극손상엔영양케어 샴푸(550ml)',
#        '미쟝센 퍼펙트세럼 샴푸(680ml)', '엘라스틴 모로칸 아르간 오일 집중영양 샴푸(680ml)',
#        '케라리스 데미지 클리닉 오리지널 샴푸(750ml)', '랩신 핸드워시 센서티브(250ml)',
#        '아이!깨끗해 항균폼 상큼레몬향(250ml)', '려 두피보호 한방염색 짙은 밤색 4.5(60g)',
#        '리엔 흑모비책크림염색 자연갈색(60g)', '미쟝센 쉽고빠른거품염색 3N 흑갈색(40g)',
#        '하기스 매직컴포트 대형 공용 팬티형 4단계(40매)', '하기스 매직컴포트 중형 공용 밴드형 3단계(66매)',
#        '하기스 매직컴포트 특대형 공용 팬티형 5단계(33매)', '메디안 치석 치약 오리지널(3개)',
#        '어드밴스 캐비티 블루(120g)', '어드밴스 캐비티 블루(3개)', '페리오 캐비티케어(3개)',
#        '오랄비 크로스액션(3개입)', '죽염 칫술 잇몸(4개)', '페리오 토탈7 칫솔 힘있는 미세모(4개)',
#        '크리넥스 데코엔소프트 3겹(24롤)', '가그린 오리지널(750ml)', '리스테린 쿨민트(750ml)',
#        '갈치(냉동, 100g)', '갈치(생물, 100g)', '고등어(생물, 300~500g)',
#        '오징어(냉동, 200~300g)', '오징어(생물, 200~300g)', '부세(200~400g)',
#        '참조기(200~400g)', '당근(흙당근, 100g)', '대파(흙대파, 500~800g)',
#        '무(줄기 없는 무, 1.5kg)', '배추(1.5~2kg)', 'CJ 행복한콩 국산콩 콩나물(280g)',
#        '국산아작아작콩나물(350g)', 'CJ 더안심 건강란(대란 15개)', 'CJ 알짜란(대란 15개)',
#        '목초를 먹고 자란 건강한 닭이 낳은 달걀(대란 15개)', '풀무원 동물복지 목초란(대란 10개)',
#        '참프레 동물복지 닭백숙(1.1kg)', '하림 자연실록백숙(830g)', '하림 토종닭백숙(1.05kg)',
#        '돼지고기 목살(100g)', '돼지고기 삼겹살(100g)', '쇠고기 등심(1+등급, 100g)',
#        '쇠고기 등심(1등급, 100g)', '쇠고기 불고기(1+등급, 100g)', '쇠고기 불고기(1등급, 100g)',
#        'CJ 비비고 왕교자(910g)', '해태 오예스(12개입)', '대림선어묵 부산어묵(300g)',
#        '오뚜기 소프트마가린(180g)', '덴마크 오리지널 치즈(14매)', '깨끗한나라 순수 시그니쳐 3겹(30롤)'],
#       dtype=object)

# %%
# 지점명을 따로 추출해서 새로운 칼럼에 추가
# Out:
# 머거본 꿀땅콩(135g)
# 허니버터아몬드(210g)
# 백설 소면(900g)
# 옛날국수 소면(900g)
# 고향만두(1.08kg)
# 비비고 왕교자(1.05kg)
# 생야채돼지고기물만두(800g)
# 백설 자른 햇당면(300g)
# 옛날 자른당면(300g)
# 국산콩두부 부침용(380g)
# 국산콩두부 찌개용(380g)
# 행복한콩 부침두부(300g)
# 행복한콩 찌개두부(300g)
# 삼양라면(5개입)
# 신라면(5개입)
# 진라면 순한맛(5개입)
# 곰표 밀가루 중력다목적용(1kg)
# 백설 찰밀가루(1kg)
# 백설 5가지 재료 부침가루(1kg)
# 오뚜기 부침가루(1kg)
# 삼립호떡 미니꿀호떡(16개입)
# 정통크림빵(3개입)
# 보노 콘스프(3개입)
# 보노 포르치니버섯스프(3개입)
# 오뚜기 크림스프(80g)
# 스페셜K 오리지널(480g)
# 켈로그 콘푸로스트(600g)
# 포스트 콘푸라이트(600g)
# 오뚜기 간편 미역국(5개입)
# 오뚜기 간편 북엇국(5개입)
# 3분 쇠고기짜장(200g)
# 3분 쇠고기카레(200g)
# 오뚜기 3분 백세카레 약간 매운맛(200g)
# 청정원 카레여왕 비프카레(160g)
# 오뚜기밥(210g)
# 오뚜기밥(3개입)
# 오뚜기밥(6개입)
# 햇반(210g)
# 햇반(3개입)
# 햇반(6개입)
# 동원 양반 쇠고기죽(287.5g)
# 동원 양반 전복죽(287.5g)
# 비비고 소고기죽(280g)
# 비비고 전복죽(280g)
# 농심 신라면 큰사발면(114g)
# 오뚜기 참깨라면 컵(110g)
# 팔도 왕뚜껑(110g)
# 오뚜기 맛있는 쇠고기미역국밥(162g)
# 오뚜기 컵밥 제육덮밥(310g)
# 햇반 컵반 고추장 제육덮밥(250g)
# 햇반 컵반 미역국밥(167g)
# 비비고 사골곰탕(500g)
# 비비고 육개장(500g)
# 오뚜기 옛날 사골곰탕(350g)
# 오뚜기 옛날 육개장(300g)
# 오리온 포카칩 오리지널(66g)
# 포테토칩 오리지날(125g)
# 롯데 자일리톨 오리지날(97g)
# 빙그레 참붕어 싸만코(150ml)
# 아이비(270g)
# 참크래커(280g)
# 돼지바(70ml)
# 메로나(75ml)
# 해태 바밤바(63ml)
# 롯데 목캔디 허브민트(217g)
# 오리온 통아몬드 캔디(90g)
# 농심 새우깡(90g)
# 롯데 월드콘 바닐라(160ml)
# 투게더 오리지널 바닐라(900ml)
# 해태 부라보콘 화이트바닐라(140ml)
# 닥터유 에너지바(40g)
# 닥터유 에너지바(4개입)
# 켈로그 레드베리 에너지바(4개입)
# 자유시간(36g)
# 자유시간(5개입)
# 핫브레이크 미니(714g)
# 몽쉘 크림(384g)
# 오리온 초코파이(18개입)
# 롯데 ABC 초코(187g)
# 롯데 빅가나 마일드(110g)
# 들기름 재래 도시락김(12팩)
# 양반 들기름이 그윽한 김(16팩)
# 대림 게맛살 큰잔치(300g)
# 동원 싱싱맛살 실속(500g)
# 삼호 안심 김밥맛살(264g)
# 삼호 안심 부산어묵(400g)
# 동원참치 라이트스탠다드(150g)
# 동원참치 라이트스탠다드(4캔)
# 마일드참치(150g)
# 마일드참치(3개)
# 사조참치 살코기 안심따개(4캔)
# 양조간장 501(500ml)
# 진간장 금F3(930ml)
# 순창 오리지널 우리쌀 찰고추장(1kg)
# 해찬들 우리쌀태양초골드(1kg)
# 해표 순창궁 태양초 100% 우리햅쌀 고추장(1.8kg)
# 동서 아카시아꿀(600g)
# 동서벌꿀(600g)
# 샘표 시골집 토장(900g)
# 순창 재래식안심생된장(1kg)
# 해찬들 재래식 된장(1kg)
# 청정원 발사믹 드레싱
# 청정원 오리엔탈 드레싱
# 오뚜기 고소한 골드 마요네즈(500g)
# 청정원 고소한 마요네즈(500g)
# 백설 자일로스 설탕(1kg)
# 백설 하얀설탕(1kg)
# 큐원 하얀설탕(1kg)
# 백설 구운소금(500g)
# 청정원 미원 맛소금(500g)
# 해표 꽃소금(1kg)
# 백설 식용유(1.5L)
# 오뚜기 콩기름 100%(900ml)
# 해표 맑고 신선한 식용유(900ml)
# 백설 건강발효 사과식초(800ml)
# 백설 건강발효 현미식초(800ml)
# 오뚜기 사과식초(900ml)
# 청정원 순창 양념듬뿍 쌈장(500g)
# 해찬들 사계절 쌈장(500g)
# 해표 순창궁 양념쌈장(500g)
# 딸기잼(500g)
# 복음자리 딸기잼(370g)
# 백설 진한참기름
# 오뚜기 참기름(320ml)
# 오뚜기카레 순한맛(100g)
# 청정원 카레여왕 구운마늘&amp;양파(108g)
# 오뚜기 토마토 케찹(500g)
# 청정원 진한 토마토 케찹(500g)
# 산들애 국내산 해물(250g)
# 청정원 맛선생 국내산해물(250g)
# 달콤한 베지밀 비(16팩)
# 달콤한 삼육두유 B
# 매일두유 담백한 맛(16팩)
# 국순당 생막걸리(750ml)
# 국순당 우국생(750ml)
# 서울장수생막걸리(750ml)
# 제주 위트 에일(500ml)
# 카스 프레쉬(500ml)
# 카스 프레쉬(6캔)
# 테라(500ml)
# 하이트 엑스트라 콜드(500ml)
# 하이트 엑스트라 콜드(6캔)
# 비타500(10개입)
# 오로나민C(10개입)
# 스프라이트(1.5L)
# 칠성사이다 제로(1.5L)
# 삼다수(2L)
# 삼다수(500ml)
# 아이시스(2L)
# 아이시스(500ml)
# 삼다수(2L*6개)
# 삼다수(500ml*20개)
# 참이슬 클래식(360ml)
# 참이슬 후레쉬(360ml)
# 처음처럼(360ml)
# 레드불 에너지 드링크(250ml)
# 롯데 핫식스(250ml)
# 몬스터 에너지(355ml)
# 게토레이 레몬(600ml)
# 파워에이드 마운틴블라스트(520ml)
# 포카리스웨트(620ml)
# 델몬트 오렌지 100(1.5L)
# 미넷메이드 오렌지(1.5L)
# 남양 17차 티백(80개입)
# 동서현미녹차(100개입)
# 맥심 티오피 마스터 라떼(275ml)
# 바리스타룰스 콜드브루 블랙(325ml)
# 아카페라 아메리카노(240ml)
# 맥스웰 하우스 오리지날(180개입)
# 맥심 모카골드 마일드(200개입)
# 카누 마일드 로스트 아메리카노(30개입)
# 프렌치카페 카페믹스(220개입)
# 코카콜라(1.8L)
# 펩시콜라(1.8L)
# 마주앙 레드(750ml)
# 진로 와인(500ml)
# 오뚜기 콘마가린(180g)
# 떠먹는 불가리스 딸기(4개)
# 바이오 플레인 요거트(4개)
# 불가리스(4개)
# 요플레 오리지널(4개)
# 이오(5개)
# 앱솔루트 명작 3단계(800g)
# 임페리얼 드림 XO 3단계(800g)
# 프리미엄 산양분유 1단계(800g)
# 그릴후랑크(600g)
# 백설 그릴 비엔나(720g)
# 의성마늘 빅그릴 비엔나(600g)
# 주부9단 프랑크소시지(900g)
# 남양유업 맛있는우유GT(1L)
# 매일우유 오리지널(900ml)
# 서울우유 흰우유(1L)
# 파스퇴르우유 후레쉬(930ml)
# 드빈치 고칼슘치즈(15매)
# 매일유업 뼈로가는 칼슘치즈(270g)
# 서울우유 체다슬라이스치즈(400g)
# 체다치즈(15매)
# 스팸 클래식(200g)
# 의성마늘 한입슬라이스햄(60g)
# 주부9단 슬라이스햄(300g)
# 마미손 고무장갑 중(2세트)
# 크린랩 고무장갑 중(2세트)
# 크린랩(22cm x 50m)
# 크린랩(30cm x 50m)
# 맥스 부탄가스(4개)
# 썬 부탄가스(4개)
# 무균무때 세정제 욕실용(900ml)
# 유한락스 레귤러(1.8L)
# 유한락스 욕실청소용(1800ml)
# 유한락스 후레쉬(1.5L)
# 홈스타 락스와세제 후로랄파인(750ml)
# 홈스타 욕실용 세정제(900ml)
# 에프킬라 에어로졸 무향(500ml)
# 컴배트 스피드 에어졸(500ml)
# 홈키파 수성 에어졸(500ml)
# 다우니 고농축 섬유유연제 엑스퍼트(2L)
# 샤프란 아우라 초고농축 섬유유연제 홀리데이판타지(2.3L)
# 피죤 섬유유연제 핑크로즈(2.1L)
# 샤프란 네이처 섬유탈취제 프레쉬 민트(300ml)
# 페브리즈 상쾌한향(370ml)
# 페브리즈 상쾌한향(900ml)
# 때가 쏙 비트 분말세제(6kg)
# 비트 트리플 액션(2.8L)
# 스파크 분말세제(6kg)
# 테크 UP 분말세제(4kg)
# 테크 베이킹소다 액체세제(3L)
# 퍼실 파워젤 액체 드럼용(2.7L)
# 퍼실 파워젤 액체 일반용(2.7L)
# 물먹는하마(3개입)
# 피죤 습기제로(8개입)
# 3M 후레쉬 슬라이드 지퍼백 중형(21cm x 16cm x 6cm)
# 손잡이 크린백(35cm x 45cm)
# 지퍼락 지퍼백 냉장 중형(20매)
# 크린롤백(25cm x 35cm)
# 크린지퍼백(18cm x 20cm)
# 메소드 주방세제 핑크(532ml)
# 자연퐁 솔잎(490ml)
# 프릴 시크릿 오브 베이킹소다 퓨어레몬향(750ml)
# 항균 트리오(973ml)
# 코디 키친타월(6롤)
# 크리넥스 안심 키친타월(6롤)
# 밥이보약 CAT 걱정없는 헤어볼
# 밥이보약 튼튼한관절
# JB 뉴 베드타임 로션(500ml)
# 정말 순한 바디밀크(450ml)
# 크리넥스 KF94 4단 마스크
# PACE6 스타일 면도날(4개)
# 플로쉴드 옐로우 면도날(4개)
# 하이드로8 면도날(8개)
# 도브 뷰티 너리싱 바디워시(1kg)
# 도브 센스티브 스킨 바디워시(1kg)
# 세이 온더바디 고보습 아이리스(900ml)
# 오가니스트 히말라야 핑크솔트 바디워시 리프레싱 민트향(865ml)
# 해피바스 라벤더 에센스 바디워시(900g)
# 도브 뷰티바(4개)
# 드봉 스위트로즈(4개)
# 해피바스 허브 라벤더 아로마 바(4개)
# 쏘피 바디피트 볼록맞춤 날개 중형(32개입)
# 좋은느낌 울트라슬림 에어핏쿠션 날개 중형(36개입)
# 좋은느낌 좋은순면 울트라 날개 중형(36개입)
# 화이트 시크릿홀 날개 중형(36개입)
# 려 함빛 극손상엔영양케어 샴푸(550ml)
# 미쟝센 퍼펙트세럼 샴푸(680ml)
# 엘라스틴 모로칸 아르간 오일 집중영양 샴푸(680ml)
# 케라리스 데미지 클리닉 오리지널 샴푸(750ml)
# 랩신 핸드워시 센서티브(250ml)
# 아이!깨끗해 항균폼 상큼레몬향(250ml)
# 려 두피보호 한방염색 짙은 밤색 4.5(60g)
# 리엔 흑모비책크림염색 자연갈색(60g)
# 미쟝센 쉽고빠른거품염색 3N 흑갈색(40g)
# 하기스 매직컴포트 대형 공용 팬티형 4단계(40매)
# 하기스 매직컴포트 중형 공용 밴드형 3단계(66매)
# 하기스 매직컴포트 특대형 공용 팬티형 5단계(33매)
# 메디안 치석 치약 오리지널(3개)
# 어드밴스 캐비티 블루(120g)
# 어드밴스 캐비티 블루(3개)
# 페리오 캐비티케어(3개)
# 오랄비 크로스액션(3개입)
# 죽염 칫술 잇몸(4개)
# 페리오 토탈7 칫솔 힘있는 미세모(4개)
# 크리넥스 데코엔소프트 3겹(24롤)
# 가그린 오리지널(750ml)
# 리스테린 쿨민트(750ml)
# 갈치(냉동, 100g)
# 갈치(생물, 100g)
# 고등어(생물, 300~500g)
# 오징어(냉동, 200~300g)
# 오징어(생물, 200~300g)
# 부세(200~400g)
# 참조기(200~400g)
# 당근(흙당근, 100g)
# 대파(흙대파, 500~800g)
# 무(줄기 없는 무, 1.5kg)
# 배추(1.5~2kg)
# CJ 행복한콩 국산콩 콩나물(280g)
# 국산아작아작콩나물(350g)
# CJ 더안심 건강란(대란 15개)
# CJ 알짜란(대란 15개)
# 목초를 먹고 자란 건강한 닭이 낳은 달걀(대란 15개)
# 풀무원 동물복지 목초란(대란 10개)
# 참프레 동물복지 닭백숙(1.1kg)
# 하림 자연실록백숙(830g)
# 하림 토종닭백숙(1.05kg)
# 돼지고기 목살(100g)
# 돼지고기 삼겹살(100g)
# 쇠고기 등심(1+등급, 100g)
# 쇠고기 등심(1등급, 100g)
# 쇠고기 불고기(1+등급, 100g)
# 쇠고기 불고기(1등급, 100g)
# CJ 비비고 왕교자(910g)
# 해태 오예스(12개입)
# 대림선어묵 부산어묵(300g)
# 오뚜기 소프트마가린(180g)
# 덴마크 오리지널 치즈(14매)
# 깨끗한나라 순수 시그니쳐 3겹(30롤)

# %%
df['판매업소'].unique()
# Out:
# array(['CU(본사)', '롯데슈퍼안양점', '롯데슈퍼김포전원점', '롯데슈퍼길동점', '롯데슈퍼구평점', '롯데슈퍼광혜원점',
#        '롯데슈퍼교문점', '롯데슈퍼광주점', '롯데슈퍼광주도평점', '롯데슈퍼광명점', '롯데슈퍼광명소하점',
#        '롯데슈퍼공릉점', '롯데슈퍼고양원흥점', '롯데슈퍼고양풍동점', '롯데슈퍼고양식사점', '롯데슈퍼고양동산점',
#        '롯데슈퍼경주용황점', '롯데슈퍼경주동천점', '롯데슈퍼개화산점', '롯데슈퍼거제상동점', '롯데슈퍼갈월점',
#        '롯데슈퍼가락점', '이마트계양점', '롯데슈퍼G화곡점', '롯데슈퍼G홍제점', '롯데슈퍼G철원점',
#        '롯데슈퍼G춘천점', '롯데슈퍼G중동점', '롯데슈퍼G전곡점', '롯데슈퍼G은평점', '롯데슈퍼G은마점',
#        '롯데슈퍼G유진점', '이마트평촌점', '이마트자양점', '롯데슈퍼수성점', '이마트월배점', '이마트여수점',
#        '이마트울산점', '이마트춘천점', '롯데슈퍼연수점', '롯데슈퍼범서점', '롯데슈퍼시흥조남점', '롯데슈퍼시흥장곡점',
#        '롯데슈퍼시흥능곡점', '롯데슈퍼시흥은행점', '롯데슈퍼송천점', '롯데슈퍼송정점', '롯데슈퍼송양점',
#        '롯데슈퍼세류역점', '롯데슈퍼세곡점', '롯데슈퍼세교점', '롯데슈퍼성주점', '롯데슈퍼성수점', '롯데슈퍼성내점',
#        '롯데슈퍼서초3동점', '롯데슈퍼서초국제점', '롯데슈퍼서창점', '롯데슈퍼상계7동점', '롯데슈퍼상계11점',
#        '롯데슈퍼삼천포점', '롯데슈퍼산본2동점', '롯데슈퍼삼성역점', '롯데슈퍼분당이매점', '롯데슈퍼분당서현점',
#        '롯데슈퍼분당구미점', '롯데슈퍼부산화명점', '롯데슈퍼부산학장점', '롯데슈퍼부산문현점', '롯데슈퍼부산정관점',
#        '롯데슈퍼봉은사로점', '롯데슈퍼복현점', '롯데슈퍼보령동대점', '롯데슈퍼방화점', '롯데슈퍼방학점',
#        '롯데슈퍼명동점', '롯데슈퍼명지점', '롯데슈퍼망포역점', '롯데슈퍼마포대흥점', '롯데슈퍼두정2점',
#        '롯데슈퍼두암점', '롯데슈퍼동탄영천점', '롯데슈퍼동탄청계2점', '롯데슈퍼덕정점', '롯데슈퍼대치4동점',
#        '롯데슈퍼대전둔산점', '롯데슈퍼대연점', '롯데슈퍼대야2점', '롯데슈퍼대구대실점', '롯데슈퍼대구현풍점',
#        '롯데슈퍼대구고산점', '롯데슈퍼대구각산점', '롯데슈퍼당수점', '롯데슈퍼당리점', '롯데슈퍼녹양점',
#        '롯데슈퍼단구점', '롯데슈퍼남현점', '롯데슈퍼남원점', '롯데슈퍼남양주호평점', '롯데슈퍼남양주청학점',
#        '롯데슈퍼남양주별내점', '롯데슈퍼남양주마석점', '롯데슈퍼남양주도곡점', '롯데슈퍼남가좌점', '롯데슈퍼남산점',
#        '롯데슈퍼김해장유점', '롯데슈퍼용운점', '롯데슈퍼중계점', '롯데슈퍼중촌점', '롯데슈퍼중계역점',
#        '롯데슈퍼연산점', '롯데슈퍼종로평창점', '롯데슈퍼정자점', '롯데슈퍼전주평화점', '롯데슈퍼정릉점',
#        '롯데슈퍼전북대점', '롯데슈퍼전농점', '롯데슈퍼장안점', '롯데슈퍼장락점', '롯데슈퍼자곡점',
#        '롯데슈퍼잠실3동점', '롯데슈퍼인후점', '롯데슈퍼인하대점', '이마트양재점', '롯데슈퍼인천청천점',
#        '롯데슈퍼인천청라점', '롯데슈퍼인천청라2점', '롯데슈퍼인천동양점', '롯데슈퍼인천문학점', '롯데슈퍼인천고잔점',
#        '롯데슈퍼송파점', '롯데슈퍼인계점', '롯데슈퍼이문점', '롯데슈퍼은평진관2점', '롯데슈퍼율전점',
#        '롯데슈퍼위례중앙점', '이마트영등포점', '롯데슈퍼월계점', '롯데슈퍼울산매곡점', '롯데슈퍼우장산점',
#        '롯데슈퍼우만점', '롯데슈퍼용인성복점', '롯데슈퍼용인점', '롯데슈퍼용인동천점', '롯데슈퍼오산점',
#        '롯데슈퍼영월점', '롯데슈퍼연수함박점', '롯데슈퍼역촌점', '롯데슈퍼역삼3점', '롯데슈퍼여의점',
#        '롯데슈퍼엑스포점', '롯데슈퍼언남점', '롯데슈퍼양산남부점', '롯데슈퍼양산가촌2점', '롯데슈퍼양산가촌점',
#        '롯데슈퍼야탑점', '롯데슈퍼안산점', '롯데슈퍼안산본오점', '롯데슈퍼안산고잔점', '롯데슈퍼아산용화점',
#        '롯데슈퍼아산용화2점', '이마트해운대점', '롯데슈퍼쌍문점', '롯데슈퍼신천점', '롯데슈퍼신부점',
#        '롯데슈퍼신반포점', '롯데슈퍼신도림점', '롯데슈퍼신동아점', '롯데슈퍼신당점', '롯데슈퍼신가점',
#        '롯데슈퍼일산점', '롯데슈퍼이천점', '이마트신월점', '이마트만촌점', '롯데슈퍼원주점', '롯데슈퍼원효로점',
#        '롯데슈퍼장위점', '이마트상봉점', '이마트서귀포점', '이마트제주점', '이마트원주점', '이마트역삼점',
#        '이마트이수점', '롯데슈퍼수원경기대2점', '이마트용산점', '롯데슈퍼프리미엄용호점', '롯데슈퍼용인남사점',
#        '롯데슈퍼프리미엄기흥점', '롯데슈퍼포항장성점', '롯데슈퍼프리미엄황금점', '롯데슈퍼부산영도점', '롯데슈퍼반포2점',
#        '롯데슈퍼프리미엄일원점', '롯데슈퍼순천오천점', '롯데슈퍼프리미엄서초점', '롯데슈퍼광명일직점',
#        '롯데슈퍼부천옥길점', '롯데슈퍼김해진영점', '롯데슈퍼율하점', '이마트광주점', '이마트의왕점', '롯데슈퍼창천점',
#        '롯데슈퍼율량점', '롯데슈퍼삼천점', '롯데슈퍼동탄청계점', '롯데슈퍼보령점', '롯데슈퍼효자점',
#        '롯데슈퍼효자2점', '롯데슈퍼화성봉담점', '롯데슈퍼회룡역점', '롯데슈퍼홍제점', '롯데슈퍼홍은점',
#        '롯데슈퍼함양점', '롯데슈퍼한빛점', '롯데슈퍼한마음점', '롯데슈퍼프리미엄문정점', '롯데슈퍼하월곡점',
#        '롯데슈퍼프리미엄도곡점', '롯데슈퍼프리미엄공덕점', '롯데슈퍼판교점', '롯데슈퍼평창진부점', '롯데슈퍼파주금촌점',
#        '롯데슈퍼탑동3점', '롯데슈퍼코엑스점', '롯데슈퍼칠곡중리점', '롯데슈퍼청계점', '롯데슈퍼천왕점',
#        '롯데슈퍼철산점', '롯데슈퍼창천2점', '롯데슈퍼창동점', '롯데슈퍼창동2점', '롯데슈퍼진주초전2점',
#        '이마트김해점', '이마트김포한강점', '이마트김천점', '이마트금정점', '이마트군산점', '이마트구로점',
#        '이마트광산점', '이마트광명소하점', '이마트과천점', '이마트경산점', '이마트경기광주점', '이마트검단점',
#        '이마트용인점', '이마트연수점', '롯데슈퍼세종고운점', '롯데슈퍼청전점', '롯데슈퍼잠원점', '롯데슈퍼하당점',
#        '롯데슈퍼수유점', '롯데슈퍼신현점', '롯데슈퍼월성점', '롯데슈퍼풍암점', '롯데슈퍼봉선점', '롯데슈퍼영주점',
#        '롯데슈퍼태안점', '롯데슈퍼경주점', '롯데슈퍼포천일동점', '롯데슈퍼상록수점', '롯데슈퍼탑동점',
#        '롯데슈퍼새서울점', '이마트광교점', '이마트가든5점', '이마트강릉점', '이마트남원점', '이마트광명점',
#        '이마트남양주점', '이마트수원점', '이마트천안서북점', '이마트제천점', '이마트동탄점', '이마트마산점',
#        '이마트구미점', '이마트분당점', '이마트산본점', '이마트의정부점', '이마트가양점', '이마트죽전점',
#        '이마트청주점', '이마트다산점', '이마트포항점', '이마트전주점', '이마트천안점', '이마트신도림점',
#        '롯데슈퍼포항점', '이마트화정점', '롯데슈퍼상남점', '롯데슈퍼문흥점', '롯데슈퍼합천점', '롯데슈퍼백석점',
#        '롯데슈퍼분당점', '롯데슈퍼평택점', '롯데슈퍼수지점', '롯데슈퍼의정부점', '이마트미아점', '이마트둔산점',
#        '이마트흥덕점', '이마트화성봉담점', '이마트하월곡점', '이마트하남점', '이마트풍산점', '이마트포천점',
#        '이마트평택점', '이마트펜타포트점', '이마트파주운정점', '이마트통영점', '이마트킨텍스점', '이마트칠성점',
#        '이마트충주점', '이마트청계천점', '이마트천호점', '이마트천안터미널점', '이마트창원점', '이마트진주점',
#        '이마트진접점', '이마트중동점', '이마트일산점', '이마트익산점', '이마트이천점', '이마트포항이동점',
#        '이마트은평점', '이마트월계점', '이마트왕십리점', '이마트오산점', '이마트양산점', '이마트영천점',
#        '이마트연제점', '이마트여주점', '이마트여의도점', '이마트양주점', '이마트안성점', '이마트안동점',
#        '이마트아산점', '이마트신제주점', '이마트순천점', '이마트수지점', '이마트속초점', '이마트세종점',
#        '이마트성수점', '이마트성서점', '이마트성남점', '이마트서수원점', '이마트서산점', '이마트사천점',
#        '이마트상주점', '이마트사상점', '이마트봉선점', '이마트보령점', '이마트별내점', '이마트반야월점',
#        '이마트문현점', '이마트묵동점', '이마트목포점', '이마트목동점', '이마트명일점', '이마트마포점',
#        '이마트동인천점', '이마트대전터미널점', '이마트파주점', '이마트창동점', '신세계백화점센텀시티점',
#        'GS더프레시구월점', 'GS더프레시대전도마점', '이마트수색점', '이마트동해점', '이마트동백점',
#        '이마트동구미점', 'GS더프레시울산구영점', 'GS더프레시북가좌점', '(주)부산경남유통 부산점',
#        '(주)농협하나로유통 성남점', '신세계백화점강남점', '이마트수서점', '이마트보라점', 'GS더프레시성북돈암점',
#        'GS더프레시장유대청점', 'GS더프레시양산가촌점', 'GS더프레시진주신안점', 'GS더프레시김해외동점',
#        'GS더프레시도청신도시점', 'GS더프레시파주청암점', 'GS더프레시인천동춘점', 'GS더프레시시흥은계점',
#        'GS더프레시세종아름점', 'GS더프레시판교운중점', 'GS더프레시송도마스터뷰점', 'GS더프레시안양메가트리아점',
#        'GS더프레시아산둔포점', 'GS더프레시배곧신도시점', 'GS더프레시아산탕정점', 'GS더프레시수원아트리움점',
#        'GS더프레시청주율량점', 'GS더프레시동소문점', 'GS더프레시대동점', '(주)농협하나로유통 김해점',
#        '(주)충북유통', '(주)농협하나로유통 달성점', '(주)농협하나로유통 광주점', 'GS더프레시경주현곡점',
#        'GS더프레시천안두정점', 'GS더프레시청주용담점', 'GS더프레시하남점', 'GS더프레시연수점',
#        'GS더프레시구포점', '(주)농협하나로유통 고양점', 'GS더프레시목동7점', '(주)농협하나로유통 수원점',
#        'GS더프레시도곡렉슬점', 'GS더프레시원주점', 'GS더프레시종로구기점', '이마트태백점',
#        'GS더프레시은평뉴타운점', 'GS더프레시서초점', 'GS더프레시서인천점', 'GS더프레시충주용산점',
#        'GS더프레시충주연수점', 'GS더프레시분당시범단지점', 'GS더프레시초읍점', 'GS더프레시부평산곡점',
#        'GS더프레시부암점', 'GS더프레시청주점', 'GS더프레시청주봉명점', 'GS더프레시청라라임점',
#        'GS더프레시부곡점', 'GS더프레시천안점', 'GS더프레시방이점', 'GS더프레시미래점', 'GS더프레시천안쌍용점',
#        'GS더프레시문경점', 'GS더프레시목동13점', 'GS더프레시명장점', 'GS더프레시명일점', 'GS더프레시만덕점',
#        'GS더프레시만수점', 'GS더프레시마포상암점', 'GS더프레시창원감계점', 'GS더프레시마산회원점',
#        'GS더프레시진해풍호점', 'GS더프레시마산점', 'GS더프레시진해여좌점', 'GS더프레시진해자은점',
#        'GS더프레시진천점', 'GS더프레시동두천점', 'GS더프레시진주평거점', 'GS더프레시양천신은점',
#        'GS더프레시원주혁신점', 'GS더프레시명지국제점', 'GS더프레시원동점', 'GS더프레시용인포곡점',
#        'GS더프레시동탄중앙점', 'GS더프레시용인점', 'GS더프레시홍천점', 'GS더프레시화명점', 'GS더프레시행신점',
#        'GS더프레시예산점', 'GS더프레시학익점', 'GS더프레시여의도점', 'GS더프레시하안8점',
#        'GS더프레시하남미사점', 'GS더프레시양산물금점', 'GS더프레시안성점', 'GS더프레시신탄진점',
#        'GS더프레시신주례점', 'GS더프레시신갈점', 'GS더프레시수원매탄점', 'GS더프레시시흥정왕점',
#        'GS더프레시포천점', 'GS더프레시수원망포점', 'GS더프레시토월점', 'GS더프레시송파점',
#        'GS더프레시송파위례점', 'GS더프레시송도그린워크점', 'GS더프레시송도점', 'GS더프레시속초교동점',
#        'GS더프레시칠곡왜관점', '(주)농협유통 양재점', '롯데슈퍼G복대2점', '롯데슈퍼G만수점',
#        '(주)농협유통 창동점', '신세계백화점본점', 'GS더프레시상계점', '(주)농협하나로유통 울산점',
#        'GS더프레시본리점', 'GS더프레시위례중앙점', 'GS더프레시거제신현점', 'GS더프레시거제옥포점',
#        'GS더프레시개금점', 'GS더프레시강릉포남점', 'GS더프레시강릉입암점', 'GS더프레시강남대치점',
#        '(주)농협대전유통', 'GS더프레시대전월평점', 'GS더프레시증평점', 'GS더프레시대전송강점',
#        'GS더프레시대방점', 'GS더프레시당진점', 'GS더프레시죽곡점', 'GS더프레시주례점', 'GS더프레시다대점',
#        'GS더프레시당진송악점', 'GS더프레시종로평창점', 'GS더프레시능곡점', 'GS더프레시전주호성점',
#        'GS더프레시남양주별내점', 'GS더프레시낙성대점', 'GS더프레시장유점', 'GS더프레시김포한강자이점',
#        'GS더프레시김포사우점', 'GS더프레시김포감정점', 'GS더프레시장유삼문점', 'GS더프레시금촌점',
#        'GS더프레시군산나운점', 'GS더프레시군포당정점', 'GS더프레시잠원점', 'GS더프레시잠실파크리오점',
#        'GS더프레시잠실점', 'GS더프레시잠실장미점', 'GS더프레시인천삼산점', 'GS더프레시의정부민락점',
#        'GS더프레시인천부개점', 'GS더프레시의왕점', 'GS더프레시의왕오전점', '롯데슈퍼G운정점', '롯데슈퍼G오남2점',
#        '롯데슈퍼G수지점', '롯데슈퍼G신곡점', '롯데슈퍼G속초조양점', '롯데슈퍼G소사점', '롯데슈퍼G속초점',
#        '롯데슈퍼G부곡점', '롯데슈퍼G복대점', '롯데슈퍼G보라점', '롯데슈퍼G목동점', '롯데슈퍼G방배점',
#        '롯데슈퍼G대림점', '롯데슈퍼G마포점', '롯데슈퍼G내손점', '롯데슈퍼G강서점', '롯데슈퍼G고양삼송점',
#        '세븐일레븐(본사)', '현대백화점천호점', 'GS25(본사)', '롯데슈퍼G구리갈매점', '신세계백화점죽전점',
#        '신세계백화점영등포점', '현대백화점목동점'], dtype=object)

# %%
brands = ['CU','롯데슈퍼','이마트','(주)부산경남유통','GS더프래시','세븐일레븐','GS25','GS수퍼마켓','홈플러스',
         '롯데마트','신세계백화점','현대백화점','롯데백화점','농협']
li_groceries = ['소면','국수','만두','당면','두부','라면','밀가루','부침가루','빵','호떡','만쥬','스프','스페설K','콘푸로스트','콘푸라이트',
               '미역국','짜장','카레','오뚜기밥','찰진밥','햇반','우동','야채죽','단팥죽','쇠고기죽','초밥','칩포테이토','포카칩','자일리톨',
               '해태아이스쿨','돼지바','메로나','바밤바','새우깡','가나파이','몽쉘크림','초코파이','초콜렛','목캔디','아이비','참크래커',
               '마가린','7even','떠먹는불가리스','바이오거트','요플레','이오','불가리스','버터','앱솔루트','분유','프리미엄프레쉬','건강한햄',
               '비앤나','롯데햄','소시지','아메리칸후랑크','의성 마늘','우유','드빈치','치즈','슬라이스햄','샌드위치햄','김밥김','맛살',
               '꽁치','어묵','참치','고추장','간장','태양초골드','황도','된장','마요네즈','딸기잼','딸기쨈','설탕','벌꿀','꽃소금',
               '옥수수유','식용유','콩기름','식초','쌈장','참기름','케찹','해물','델몬트','오렌지','현미녹차','베지밀','두유','생막걸리',
               '우국생','HITE','오비골든라거','카스 프레쉬','비타500','비타파워','스프라이트','칠성사이터','삼다수','아이시스','워터라인',
               '참이슬','처음처럼','비락식혜','게토레이','파워에이드','포카리스웨트','순보리차','옥수수수염차','레쓰비','맥스웰 하우스',
               '맥심 티오피','칸타타','맥심모카골드','테이스터스초이스','프렌치까페','카페라떼','코카콜라','펩시콜라','카페오레','김치',
               '콩나물','단무지','월드콘','박카스','배추','부라보콘','구론산','스타벅스','양파','참붕어','몽쉘','칠성사이다','풀무원','스페셜K',
               '네스카페','오리온','감자','고구마','버섯','애호박','대파','막걸리','토스트','남양','당근','동서','마늘','시금치','엔젤리너스','오뚜기',
               '컨피던스','풋고추','샘표','오이','국내산','고등어','롯데','오징어','백설','삼립','씨그램','레드불','비비고','떡','몬스터','탄산수','청정원',
                '오리온','켈로그','팔도','하선정','해태','엔제리너스','스팸','들기름','트레비','굴소스','땅콩','아몬드','적상추','쪽파','생강','양반',
                '투게더','줄기 없는 무', '깻잎','가지', '카스','오비라거','자유시간','하이트','핫브레이크']

li_meat = ['삼겹살','쇠고기등심','쇠고기불고기','달걀','목초란','토종닭','알짜란','백숙','특란','갈치','삼치','참조기','건강란',
          '쇠고기 등심','쇠고기 불고기','돼지고기 목살','부세']

li_necessaries = ['페리오','핸드크림','니베아','해피바스','클링스','치약','2080','샴푸','하기스','면도날','3날','린스','컨디셔너',
                 '이자녹스 테르비나','iope 슈퍼바이탈','염색','미쟝센','비겐크림폼','선블럭','뉴트로지나','핸드워시','아이!깨끗해',
                 '비누','좋은느낌','화이트 New','위스퍼','바디피트','로션','Dr.','바디워시','온더바디','AVEENO','티슈','가그린','리스테린',
                 'TRY','BYC','호일','비비안','러닝','비너스','테크','크린','후레시지퍼백','참그린','지퍼락','롯데팩','후레쉬백',
                 '키친타올','홈스타','물먹는하마','물먹는 하마','깨끗한나라','항균트리오','페브리즈','비트','무균무때','옥시싹싹',
                 '샤프란','락스','피죤','다우니','맥스','가스','크린랩','듀라셀','마미손','위청수','타우스액','까스명수',
                 '데톨','후레쉬랩','화이트','향균트리오','데톨','메디안','롯데랩','메디안','벡셀','드봉 스위트로즈','도브','깨끗한 나라','P&G',
                  '퍼실','크리넥스','제이디','퍼펙트','에너자이저','닥터','생록천','쉐리','고무장갑','자연퐁','세이프',
                 '스파크','어드밴스 캐비티','알프스디','보솜이','표백제','세정제','팬티','컴배트',
                 '홈키파','에프킬라','임페리얼','챕스틱','클린앤클리어','오랄비','향균 트리오']

# %%
def find_brand(x):
    global brands
    for bra in brands:
        if bra in x:
            return bra
    return np.nan

def categorization(x):
    global li_meat
    global li_groceries
    global li_necessaries
    global else_li
    if x == '무':
        return '식품'
    for meat in li_meat:
        if meat in x:
            return '축산물'
    for gro in li_groceries:
        if gro in x:
            return '식품'
    for nec in li_necessaries:
        if nec in x:
            return '생필품'
    return np.nan

# %%
df_2014_1 = pd.read_csv('./data/2014년 1월 가격데이터.csv', encoding='ansi')

# %%
uni_ =  df_2014_1.상품명.unique()

# %%
df_2014_3['브랜드'] = np.nan

# %%
df_2014_3 ['브랜드'] = df_2014_3['판매업소'].apply(find_brand)

# %%
df_2014_3 ['상품명'].unique()
# Out:
# array(['진간장 금F3', '해찬들 우리쌀태양초골드', '대상 사과식초', '오뚜기 사과식초',
#        '부라보콘 5개입 화이트바닐라', '하림 자연실록백숙 830g', '김밥김', '샘표 김치찌개용 꽁치',
#        '마일드참치(묶음)', '7even(4개묶음)', '의성 마늘 프랑크(350g)',
#        '매일우유 오리지널(ESL)(1000ml)', '남양유업 드빈치(300g)', '서울우유 체다슬라이스치즈(400g)',
#        '참작 참잘만든 슬라이스햄', '순창 오리지널 우리쌀 찰고추장 ', '니베아 SOS',
#        '마미손_고무장갑(중) (단품)', '썬 부탄가스', '물먹는하마 슬림', '뽑아쓰는 크린백',
#        '자연퐁 솔잎향 세균설거지(용기)', '행복한콩 국산콩두부(찌개용)', '알프스가스', '유한락스 레귤러',
#        '피죤 용기 옐로미모사', '샤프란 케어 상쾌한 향', '퍼실 액체세제 드럼용 2.7L', '삼양라면 5개입',
#        '백설 중력밀가루(1kg)', '무균무때(욕실용)', '디럭스키친타올', '1964 정통 크림빵',
#        '청정원 우리쌀 크림스프', '물먹는하마 참숯', '3M후레쉬백', '세이프 유기농 발아현미 리필',
#        '생야채물만두(700g)', '백설부침가루(1kg)', '마니커_국내산 토종닭 1050g 팩', '칠성사이다',
#        '맥스웰 하우스 오리지날', '크리넥스 알로에플러스 미용티슈', '닥터 아토마일드(묶음)', 'JB 뉴 베드타임 로션',
#        '도브 뷰티바', '니베아 Fresh Sun Lotion', '더블리치 간편염색 (4G, 자연갈색)',
#        '미쟝센 쉽고빠른거품염색(3N 흑갈색)', '프렌치까페믹스', '잘풀리는집 보습미용티슈',
#        '그린핑거 순한자연보습 베이비로션(320ml)', '해피바스 허브 라벤더 아로마 바', '비겐크림폼(짙은 갈색)',
#        'NEW하기스 네이처메이드 남아용 대형', '가그린 레귤러', '도브 뷰티 너리싱 바디워시', '하이드로5 면도날',
#        '엘라스틴 맥시마이징 볼륨 샴푸', '크린랩(30cm x 50m)', '다우니 고농축 블루튤립과 달콤한 라일락',
#        '부드러운숙식빵', '해피바스 로즈에센스 로맨틱 바디워시', '뉴트로지나릴렉싱바디워시',
#        '뉴하기스 프리미어4 남아용 대형', 'Neut.핸드크림', '맥스 CRV 폭발방지 부탄가스',
#        '옥시싹싹 락스로싹 세제로싹', '홈스타 곰팡이 싹', '리스테린 쿨민트', '클링스 어드밴스드 클린민트(묶음)',
#        '오뚜기 크림스프', '센쿡찰진밥(단품)', '동원참치 라이트스탠다드(단품)', '마일드참치(단품)', '식빵위의네모',
#        '해표 꽃소금', '청정원 순창 쌈장', '참진한참기름(해표)', '오뚜기카레 순한맛', '진한케찹(대상)',
#        '풀무원 새콤달콤 유부(330g)', '쇠고기등심(1+등급)', '프레시안삼호부산어묵',
#        '생야채돼지고기물만두(400g*2봉)', '고소한국산콩두부(부침용)(대상)', '진라면(순한맛) 5개입',
#        '큐원 영양강화밀가루(1kg)', '맛있는 옛날 꿀호떡', '개성 감자만두', '곰표 다목적밀가루(1kg)',
#        '오뚜기부침가루(1kg)', 'CJ 가쓰오 우동 4인용', '쇠고기불고기(1+등급)', '쇠고기불고기(1등급)',
#        '보노콘스프', '스페셜K 오리지널(480g)', '포스트 콘푸라이트(600g)', '맛있는오뚜기밥(6개입) ',
#        '하림 토종닭백숙(1050g)', '국산콩두부(찌개용)(풀무원)', '찰토스트식빵', '쇠고기등심(1등급)',
#        'I cant believe(60%) 저지방마가린(212.5g*2개)', '켈로그 콘푸로스트(600g)',
#        '국내산 목초를 먹고자란 건강한 닭이 낳은 달걀(15구)', '옥수수 마가린(200g)',
#        '프리미엄 산양분유 1단계(800g)', 'HITE(단품)', '오비골든라거(단품)', '참이슬 클래식',
#        '아이시스(500ml)', '엔제리너스 카페라떼', '코카콜라(1.5L)', '펩시콜라(1.5L)',
#        '뉴트로지나 Ultra Sheer Dry-Touch Sun Block', '아비노 컨티뉴어스 프로텍션 선블럭',
#        '마하3 면도날', '미장센 펄샤이닝모이스쳐 샴푸', '2080 오리지날 블루 충치케어(단품)',
#        '이오 20s (3개묶음)', '목우촌 주부9단 소시지(500g)', '남양유업 맛있는우유GT(1000ml)',
#        '웰빙 다시다 산들애 국내산해물', '종가집 풍부한 포기김치(1.9kg)',
#        '새콤달콤 간편한 유부초밥 박사(160g*2)', '프레시안 주부초밥왕(320g)',
#        '임페리얼분유XO 1단계(800g)', '딸기잼 ', '2080 오리지날 블루 충치케어(묶음)',
#        '메디안 후레쉬마린(묶음)', '후레쉬랩(25cm x 50m)(3M)', '배니시 옥시크린 O2액션',
#        '오리지널 요플레(4개묶음)', '유한락스 후레쉬', '물먹는 하마 옷장용', '옛날당면',
#        '크린랩_고무장갑(중) (묶음)', '박카스F(단품)', '롯데비앤나(400g)', '순창재래식안심생된장 ',
#        '해찬들 재래식 된장 ', '고소한마요네즈(대상)', '맑고신선한옥수수유', '맑고신선한해표식용유',
#        '해표 순창 궁 발아콩 12가지 양념쌈장', '설록현미녹차 100포', '국순당 우국생', '아이시스(2L)',
#        '참이슬 후레쉬', '옥수수수염차', '참크래커', '매일유업 뼈로가는 칼슘치즈(270g)', '롯데슬라이스햄',
#        '햇반(엄마가해주신밥, 단품)', '돼지고기삼겹살', '떠먹는불가리스 딸기 오리지날(4개묶음)', '무',
#        '국산아작아작콩나물', '동서현미녹차 100포', '서울장수생막걸리', '삼다수(500ml)',
#        '파워에이드 마운틴블라스트(600ml)', '크린랩(22cm x 50m)', '동원참치 라이트스탠다드(묶음)',
#        '자연의 시작 불가리스 사과 (4개묶음)', '오뚜기황도', '신라면 5개입', '리엔 흑모비책크림염색 자연갈색',
#        '샤프란 코튼 앤 크림', '옥시싹싹(욕실용)', '3분 쇠고기 짜장', 'CJ 더 건강한햄 그릴후랑크(350g)',
#        '푸드림 하얀설탕', '맛선생 해물', '토마토케찹(오뚜기)', '복음자리 딸기쨈', '해찬들 사계절 쌈장',
#        '고소한참기름(오뚜기)', '배추', '생야채 유부초밥(380g)', '풀무원 생 가쓰오 우동',
#        '행복한콩 제주산콩 친환경콩나물', '해태아이스쿨', '초코파이 18개입', '맥심 티오피 마스터블렌드(275ml)',
#        '국화빵 수(묶음)', '오리지널 단팥빵', '오뚜기 꽁치', '3분 쇠고기 카레', '바밤바(묶음)',
#        '백설국내콩기름', '양파', '벡셀AA*2입', '퓨어가닉허브로션', '고소한골드마요네즈(오뚜기)',
#        '월드콘XQ 5개입', '백설 하얀설탕', '사양벌꿀', '롯데목캔디 허브', '달콤한 베지밀 비',
#        '포카칩 오리지날', '부라보콘(단품) 화이트바닐라', '처음처럼', '칸타타 원두커피 프리미엄 블렌드(275ml)',
#        '지퍼락 지퍼백(중)', '맛있는 미역국', '알짜란(15구)', '서울우유 체다슬라이스치즈(200g)',
#        '큐원 하얀설탕', '백설 국내산 사과식초', '서울우유 흰우유(1000ml)', '아비노베이비데일리모이스춰로션',
#        '위스퍼 리프레시 클린케어 중형날개', '해피바스 내추럴24핸드크림', '에너자이저AA*2입',
#        '쿠킹호일(25cm x 30m)(대한) ', '동원복숭아(황도) 슬라이스', '진한참기름(CJ)',
#        '국화빵 수(단품)', '돼지바(묶음)', '몽쉘 크림', '비타파워', '크리넥스데코앤소프트', '옛날국수소면',
#        '미닛메이드 오리지날 오렌지 100', '삼다수(2L)', '스타벅스 커피라떼', '메로나(묶음)',
#        '오뚜기식용유(콩100%)', '뼈로가는 칼슘두유 담백한맛', 'Dr. ato(민감성건성피부보습)',
#        '바디피트 볼록맞춤울트라중형', '맥심모카골드', '아이!깨끗해 항균폼 상큼레몬향', '게토레이 레몬',
#        '동서 순보리차', '세이 온더바디 고보습 아이리스', '참붕어 싸만코(묶음)', '월드콘XQ(단품)', '스프라이트',
#        '송염치약(묶음)', '물먹는하마 신발용', '위청수(단품)', '드봉 스위트로즈', '샘표소면(1.1kg)',
#        '백설 미역국', '대림게맛살큰잔치', '싱싱맛살', '샘표황도', '카스 프레쉬(단품)',
#        '삼다수(500ml, 묶음)', '포카리스웨트', '동원 양반 국산100% 쇠고기죽',
#        '듀라셀 울트라 파워체크 AA*2입(피엔지)', '롯데호일(30cm x 30m) ',
#        '화이트 NEW시크릿홀 울트라 날개 중형', '레쓰비 마일드(175ml)', '돼지바(단품)', '알뜨랑비누 핑크',
#        'PACE 6 면도날', '비타500(단품)', 'CJ햇당면 ', '프레시안 샌드위치햄', 'CJ햇반 단팥죽',
#        '목초란 10구', '바밤바(단품)', '가나파이 오리지날 12개입', '동원 꽁치', '오뚜기파운드마가린(450g)',
#        '올리브유저지방 마가린(200g)', '앱솔루트 명작 1단계(800g)', '숨쉬는콩된장 구수한맛',
#        '달콤한 삼육두유 B', '듀라셀 AA *4입', '국순당 생막걸리', 'CJ 참그린 ', '사누끼 가쓰오 생우동',
#        '퍼실 액체세제 일반용 2.7L', '도브 센스티브스킨 바디워시 ', '매일바이오거트(4개묶음)', '테크(단품)',
#        '하선정 숯 김밥단무지', '볶음 짜장', '테크표백젤', '센쿡찰진밥(3개입)', '도브 데미지 볼륨 부스트 샴푸',
#        '까스명수(단품)', '양반 구운 김밥김', '쉐리 후레쉬 시트 카밍라벤더', '새우깡 ', '카스 프레쉬 6캔',
#        '메로나(단품)', '델몬트 스카시플러스 100', 'HITE(6캔)', '미쟝센 샤이닝에센스크림컬러 6C(자연밤색)',
#        '오비골든라거 6캔', '비타500(묶음)', '악마의유혹 프렌치 카페오레',
#        '니베아 Face Sun Block Moisturizing Cream', '삼다수(2L, 묶음)',
#        '맛있는오뚜기밥(단품)', '롯데호일(25cm x 30m)', '듀라셀 울트라 파워체크 AAA*2입', '크린백',
#        '사조 꽁치', '약간매운맛 카레', '청정원 야채죽', '페브리즈 깨끗한 무향(370)',
#        '좋은느낌 스키니핏 하이퍼 울트라 날개 중형', '데톨 오리지날 허브', '찬마루 김밥단무지',
#        '동원양반포기김치(2.2kg)', '비트(단품)', '햇살담은 자연숙성진간장', '남양유업 드빈치(200g)',
#        '생야채돼지고기물만두(650g+200g)', '칩포테이토 오리지날', '백설꽃소금', '아이비',
#        '영진구론산G 10병', '대한웰빙호일 15m*25m', '박카스D', '주부초밥짱(480g)',
#        '매일 카페라떼 마일드', '동서벌꿀', '생록천(단품)', '햇반(엄마가해주신밥, 6+2개입)',
#        '올에이 중형 고무장갑', '대림선어묵 부산어묵', '비락식혜', '홈스타 제습과 방충을 한번에',
#        '가나마일드초콜렛 2개입', '가나마일드초콜렛(단품)', 'iope 슈퍼바이탈 에멀젼', '박카스F 10병',
#        '대림오양맛살', '센쿡찰진밥(6개입)', '오뚜기 야채죽', '매일유업 뼈로가는 칼슘치즈(180g)',
#        '깨끗한나라 키친타올', '제일제면소 소면', '파워크린', '참붕어 싸만코(단품)', '워터라인',
#        'CJ하선정 포기김치(2.0kg)', '테이스터스초이스 오리지날', '미장센 펄샤이닝모이스쳐 린스',
#        '페브리즈 깨끗한 무향(900)', '항균트리오', '행복한콩 깊은바다두부(부침용)(CJ)',
#        '맥스웰 하우스 오리지날(175ml)', '무가염버터(450g)', '팬틴 바운시 볼륨케어 샴푸',
#        'TRY 후레쉬남티셔츠*3매', '팬틴 바운시 볼륨케어 컨디셔닝 린스', '엘라스틴 맥시마이징 볼륨 컨디셔너',
#        '페이스선블럭 화이트닝', '퍼펙트 하나로 리필', '자일리톨 애플민트', '사조참치마일드(묶음)',
#        '해피바스 항균 레몬그라스 핸드워시', '페리오 캐비티케어(묶음)', '모닝버터(해바라기유)(200g)',
#        'iope 슈퍼바이탈 소프너', 'iope 슈퍼바이탈 세럼', '비트 O2 살균표백제', '햇바삭김 김밥김',
#        '도브 데미지 볼륨 부스트 린스', '쿠킹호일(20cm x 30m)(삼아)', '쿠킹호일(25cm x 30m)(삼아)',
#        '깨끗한나라 순수 3겹데코', '마미손_고무장갑(중) (묶음)', '삼성구론산D 10병', '타우스액 10병',
#        '크린지퍼백', '한입가득 밤형만쥬', '자일리톨', '제이디 100수 반팔러닝', 'TRY 후레쉬남러닝*3매',
#        '비너스 올풀림방지 팬티 스타킹', '제이디 100수런닝 ', 'BYC 데오니아 남러닝',
#        '비비안 하이서포트 고탄력 팬티스타킹', '마니커 국내산 토종닭 1050g 팩', '깨끗한 나라(묶음)'],
#       dtype=object)

# %%
for year in range(2014, 2022):
    df_year = pd.DataFrame()
    for month in range(1,13):
        df = pd.read_csv('./data/{}년 {}월 가격데이터.csv'.format(year,month), encoding='ansi')
        try:
            df.drop('제조사', axis = 1, inplace=True)
        except:
            pass
        try:
            df.drop('세일여부', axis = 1, inplace=True)
        except:
            pass
        try:
            df.drop('원 플러스 원', axis = 1, inplace=True)
        except:
            pass
        try:
            df.drop('1+1', axis = 1, inplace=True)
        except:
            pass
        
        df['브랜드'] = df['판매업소'].apply(find_brand)
        df.dropna(how = 'any', inplace = True)
        df['상품명'] = df.상품명.astype('category')
        df['브랜드'] = df.브랜드.astype('category')
        df['분류'] = df.상품명.apply(categorization)
        df['분류'] = df.분류.astype('category')
        df['조사일'] = '{}-{}'.format(year,month)
#         df['조사일'] = pd.to_datetime(df.조사일)
#         df.set_index('브랜드', inplace = True)
        grouped = df.groupby(['조사일','브랜드','분류']).판매가격.mean()
        temp = grouped.unstack().reset_index()
        temp.to_csv('./avg_data/{}년{}월 평균.csv'.format(year,month), encoding='ansi')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9180/1763689585.py in <module>
#       2     df_year = pd.DataFrame()
#       3     for month in range(1,13):
# ----> 4         df = pd.read_csv('./data/{}년 {}월 가격데이터.csv'.format(year,month), encoding='ansi')
#       5         try:
#       6             df.drop('제조사', axis = 1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/2021년 1월 가격데이터.csv'

# %%
df = pd.read_csv('./avg_data/2014년1월 평균.csv', index_col = 2, encoding = 'ansi')
for year in range(2014, 2021):
    for month in range(1,13):
        if year == 2014 and month == 1:
            continue
        temp = pd.read_csv('./avg_data/{}년{}월 평균.csv'.format(year,month), index_col = 2, encoding = 'ansi')
        df = df.append(temp)

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df['조사일'] = pd.to_datetime(df.조사일)

# %%
df = df.sort_values('조사일')

# %%
df = df.fillna(method='ffill')

# %%
df.index
# Out:
# Index(['CU', '홈플러스', '현대백화점', '이마트', '세븐일레븐', '롯데슈퍼', '신세계백화점', '롯데마트', '농협',
#        'GS수퍼마켓',
#        ...
#        '신세계백화점', '세븐일레븐', '롯데백화점', '이마트', '농협', 'GS수퍼마켓', 'GS25', '(주)부산경남유통',
#        '롯데마트', '현대백화점'],
#       dtype='object', name='브랜드', length=972)

# %%
df.loc['롯데마트']
# Out:
#             조사일          생필품           식품          축산물
# 브랜드
# 롯데마트 2014-01-01  8834.278351  4463.747154  6142.753086
# 롯데마트 2014-02-01  8876.398887  4467.511327  6364.333333
# 롯데마트 2014-03-01  8712.228535  4468.919271  6128.800000
# 롯데마트 2014-04-01  8811.441224  4599.322090  6032.026749
# 롯데마트 2014-05-01  8698.825655  4620.410279  5885.226337
# ...         ...          ...          ...          ...
# 롯데마트 2020-08-01  8150.451461  2478.526786  5169.443038
# 롯데마트 2020-09-01  9404.587156  2469.377907  6222.642857
# 롯데마트 2020-10-01  9439.769053  2259.777228  5204.233333
# 롯데마트 2020-11-01  9422.844037  1658.262500  5769.040000
# 롯데마트 2020-12-01  9478.532110  1850.985185  4997.062500
#
# [84 rows x 4 columns]

# %%
for i in df.index.unique()[:1]:
    df.loc[i].plot()

# %%
# 생필품도 리스트를 만들어야할꺼같음
# 식품 리스트 확장
# df를 브랜드별로 만들어 저장
temp['조사일']
# Out:
# 0     2014-12
# 1     2014-12
# 2     2014-12
# 3     2014-12
# 4     2014-12
# 5     2014-12
# 6     2014-12
# 7     2014-12
# 8     2014-12
# 9     2014-12
# 10    2014-12
# 11    2014-12
# Name: 조사일, dtype: object

# %%
df_2014_3.drop('제조사',axis=1)
# Out:
#                     상품명         조사일   판매가격      판매업소 세일여부 1+1    브랜드
# 0               진간장 금F3  2014-02-28   5350  롯데마트 원주점    N   N   롯데마트
# 1          해찬들 우리쌀태양초골드  2014-02-28  12300  롯데마트 원주점    N   N   롯데마트
# 2               대상 사과식초  2014-02-28   2000  롯데마트 원주점    N   N   롯데마트
# 3              오뚜기 사과식초  2014-02-28   1900  롯데마트 원주점    N   N   롯데마트
# 4       부라보콘 5개입 화이트바닐라  2014-02-28   7500  롯데마트 원주점    N   N   롯데마트
# ...                 ...         ...    ...       ...  ...  ..    ...
# 191711         HITE(6캔)  2014-03-28   7660   이마트해운대점    N   N    이마트
# 191712         HITE(6캔)  2014-03-28   7660    이마트계양점    N   N    이마트
# 191713         HITE(6캔)  2014-03-28   7660   이마트 용산점    N   N    이마트
# 191714         HITE(6캔)  2014-03-28   8400      양동시장    N   N    NaN
# 191715         HITE(6캔)  2014-03-28   7300  롯데백화점창원점    N   N  롯데백화점
#
# [191716 rows x 7 columns]

# %%
df.상품명.unique()
# Out:
# array(['샘표소면(1.1kg)', '옛날국수소면', '제일제면소 소면', '찰국수소면', '개성 감자만두',
#        '생야채돼지고기물만두(400g*2봉)', '생야채돼지고기물만두(650g+200g)', '생야채물만두(700g)',
#        'CJ햇당면 ', '옛날당면', '고소한국산콩두부(부침용)(대상)', '국산콩두부(찌개용)(풀무원)',
#        '행복한콩 국산콩두부(찌개용)', '행복한콩 깊은바다두부(부침용)(CJ)', '삼양라면 5개입', '신라면 5개입',
#        '진라면(순한맛) 5개입', '곰표 다목적밀가루(1kg)', '백설 중력밀가루(1kg)',
#        '큐원 영양강화밀가루(1kg)', '백설부침가루(1kg)', '오뚜기부침가루(1kg)', '1964 정통 크림빵',
#        '맛있는 옛날 꿀호떡', '오리지널 단팥빵', '한입가득 밤형만쥬', '보노콘스프', '오뚜기 크림스프',
#        '청정원 우리쌀 크림스프', '기린바로구워토스트', '부드러운숙식빵', '찰토스트식빵',
#        '스페셜K 오리지널(480g)', '켈로그 콘푸로스트(600g)', '포스트 콘푸라이트(600g)', '맛있는 미역국',
#        '백설 미역국', '3분 쇠고기 짜장', '3분 쇠고기 카레', '볶음 짜장', '약간매운맛 카레',
#        '맛있는오뚜기밥(3+2)', '맛있는오뚜기밥(6개입) ', '맛있는오뚜기밥(단품)', '센쿡찰진밥(3개입)',
#        '센쿡찰진밥(6개입)', '센쿡찰진밥(단품)', '햇반(엄마가해주신밥, 3+1개입)',
#        '햇반(엄마가해주신밥, 6+2개입)', '햇반(엄마가해주신밥, 단품)', 'CJ 가쓰오 우동 4인용',
#        '면사랑 가쓰오 우동 4인용', '사누끼 가쓰오 생우동', '풀무원 가쓰오 우동 4인용', '풀무원 생 가쓰오 우동',
#        'CJ햇반 단팥죽', '동원 양반 국산100% 쇠고기죽', '오뚜기 야채죽', '청정원 야채죽',
#        '새콤달콤 간편한 유부초밥 박사(160g*2)', '생야채 유부초밥(380g)', '주부초밥짱(230g)',
#        '주부초밥짱(480g)', '풀무원 새콤달콤 유부(330g)', '풀무원_새콤달콤 유부초밥(4인)',
#        '프레시안 국산콩두부초밥왕', '프레시안 주부초밥왕(320g)', '칩포테이토 오리지날', '포카칩 오리지날',
#        '자일리톨', '자일리톨 76%', '자일리톨 애플민트', '자일리톨 오리지날', '해태아이스쿨',
#        '국화빵 수(단품)', '국화빵 수(묶음)', '참붕어 싸만코(단품)', '참붕어 싸만코(묶음)', '돼지바(단품)',
#        '돼지바(묶음)', '메로나(단품)', '메로나(묶음)', '바밤바(단품)', '바밤바(묶음)', '새우깡 ',
#        '부라보콘 5개입 화이트바닐라', '부라보콘(단품) 화이트바닐라', '월드콘XQ 5개입', '월드콘XQ(단품)',
#        '가나파이 오리지날 12개입', '몽쉘 크림', '초코파이 18개입', '가나마일드초콜렛 2개입',
#        '가나마일드초콜렛(단품)', '롯데목캔디 허브', '아이비', '참크래커',
#        'I cant believe(60%) 저지방마가린(212.5g*2개)', '오뚜기파운드마가린(450g)',
#        '옥수수 마가린(200g)', '올리브유저지방 마가린(200g)', '7even(4개묶음)',
#        '떠먹는불가리스 딸기 오리지날(4개묶음)', '매일바이오거트(4개묶음)', '오리지널 요플레(4개묶음)',
#        '오리지널 요플레(단품)', '이오 20s (3개묶음)', '자연의 시작 불가리스 사과 (4개묶음)',
#        '모닝버터(해바라기유)(200g)', '무가염버터(450g)', '서울우유 고소한버터', '소와나무 모닝버터 오메가3',
#        '앱솔루트 명작 1단계(800g)', '앱솔루트 프리미엄명작 1단계', '임페리얼분유XO 1단계(800g)',
#        '프리미엄 산양분유 1단계(800g)', '프리미엄프레쉬 1단계 ', 'CJ 더 건강한햄 그릴후랑크(350g)',
#        '롯데비앤나(400g)', '롯데햄켄터키프랑크', '목우촌 주부9단 소시지(500g)', '아메리칸후랑크',
#        '의성 마늘 프랑크(350g)', '남양유업 맛있는우유GT(1000ml)',
#        '매일우유 오리지널(ESL)(1000ml)', '서울우유 흰우유(1000ml)', '남양유업 드빈치(200g)',
#        '남양유업 드빈치(300g)', '매일유업 뼈로가는 칼슘치즈(180g)', '매일유업 뼈로가는 칼슘치즈(270g)',
#        '서울우유 체다슬라이스치즈(200g)', '서울우유 체다슬라이스치즈(400g)', '롯데슬라이스햄', '식빵위의네모',
#        '참작 참잘만든 슬라이스햄', '프레시안 샌드위치햄', '김밥김', '양반 구운 김밥김', '햇바삭김 김밥김',
#        '대림게맛살큰잔치', '대림오양맛살', '싱싱맛살', '동원 꽁치', '사조 꽁치', '샘표 김치찌개용 꽁치',
#        '오뚜기 꽁치', '대림선어묵 부산어묵', '프레시안삼호부산어묵', '동원참치 라이트스탠다드(단품)',
#        '동원참치 라이트스탠다드(묶음)', '마일드참치(단품)', '마일드참치(묶음)', '사조참치마일드(묶음)',
#        '진간장 금F3', '햇살담은 자연숙성진간장', '순창 오리지널 우리쌀 찰고추장 ', '해찬들 우리쌀태양초골드',
#        '동원복숭아(황도) 슬라이스', '샘표황도', '오뚜기황도', '순창재래식안심생된장 ', '숨쉬는콩된장 구수한맛',
#        '해찬들 재래식 된장 ', '딸기잼 ', '복음자리 딸기쨈', '고소한골드마요네즈(오뚜기)', '고소한마요네즈(대상)',
#        '동서벌꿀', '백설 하얀설탕', '큐원 하얀설탕', '푸드림 하얀설탕', '백설꽃소금', '해표 꽃소금',
#        '맑고신선한옥수수유', '맑고신선한해표식용유', '백설국내콩기름', '오뚜기식용유(콩100%)', '2배 사과식초',
#        '대상 사과식초', '백설 국내산 사과식초', '오뚜기 사과식초', '찐보리와 콩으로 야채맛 살리는 쌈장',
#        '청정원 순창 쌈장', '해찬들 사계절 쌈장', '해표 순창 궁 발아콩 12가지 양념쌈장', '고소한참기름(오뚜기)',
#        '진한참기름(CJ)', '참진한참기름(해표)', '오뚜기카레 순한맛', '진한케찹(대상)', '토마토케찹(오뚜기)',
#        '맛선생 해물', '웰빙 다시다 산들애 국내산해물', '델몬트 스카시플러스 100',
#        '미닛메이드 오리지날 오렌지 100', '동서현미녹차 100포', '설록현미녹차 100포', '달콤한 베지밀 비',
#        '달콤한 삼육두유 B', '뼈로가는 칼슘두유 담백한맛', '국순당 생막걸리', '국순당 우국생', '서울장수생막걸리',
#        'HITE(6캔)', 'HITE(단품)', '오비골든라거 6캔', '오비골든라거(단품)', '카스 프레쉬 6캔',
#        '카스 프레쉬(단품)', '비타500(단품)', '비타500(묶음)', '비타파워', '스프라이트', '칠성사이다',
#        '삼다수(2L)', '삼다수(2L, 묶음)', '삼다수(500ml)', '삼다수(500ml, 묶음)',
#        '아이시스(2L)', '아이시스(500ml)', '워터라인', '참이슬 클래식', '참이슬 후레쉬', '처음처럼',
#        '비락식혜', '게토레이 레몬', '파워에이드 마운틴블라스트(600ml)', '포카리스웨트', '동서 순보리차',
#        '옥수수수염차', '레쓰비 마일드(175ml)', '맥스웰 하우스 오리지날(175ml)',
#        '맥심 티오피 마스터블랜드(200ml)', '맥심 티오피 마스터블렌드(275ml)',
#        '칸타타 원두커피 프리미엄 블렌드(175ml)', '칸타타 원두커피 프리미엄 블렌드(275ml)',
#        '맥스웰 하우스 오리지날', '맥심모카골드', '테이스터스초이스 오리지날', '프렌치까페믹스',
#        '매일 카페라떼 마일드', '스타벅스 커피라떼', '악마의유혹 프렌치 카페오레', '엔제리너스 카페라떼',
#        '코카콜라(1.5L)', '펩시콜라(1.5L)', '국내산 목초를 먹고자란 건강한 닭이 낳은 달걀(15구)',
#        '목초란 10구', '알짜란(15구)', '마니커 국내산 토종닭 1050g 팩', '하림 자연실록백숙 830g',
#        '하림 참진토종닭', '하림 토종닭백숙(1050g)', '돼지고기삼겹살', '쇠고기등심(1+등급)',
#        '쇠고기등심(1등급)', '쇠고기불고기(1+등급)', '쇠고기불고기(1등급)', '찬마루 김밥단무지',
#        '하선정 숯 김밥단무지', '무', '배추', '양파', '국산아작아작콩나물', '국산콩 무농약 옛맛콩나물',
#        '행복한콩 제주산콩 친환경콩나물', 'CJ하선정 통김치(2.0kg)', 'CJ하선정 포기김치(2.0kg)',
#        '동원양반포기김치(2.2kg)', '종가집 풍부한 포기김치(1.9kg)', '듀라셀 AA *4입',
#        '듀라셀 울트라 파워체크 AA*2입(피엔지)', '듀라셀 울트라 파워체크 AAA*2입', '듀라셀AA*2입',
#        '벡셀AA*2입', '에너자이저AA*2입', '마미손_고무장갑(중) (단품)', '마미손_고무장갑(중) (묶음)',
#        '올에이 중형 고무장갑', '크린랩_고무장갑(중) (묶음)', '롯데랩(20cm x 50m)',
#        '크린랩(22cm x 50m)', '크린랩(30cm x 50m)', '후레쉬랩(25cm x 50m)(3M)',
#        '맥스 CRV 폭발방지 부탄가스', '맥스 new 폭발방지 부탄', '썬 부탄가스', '알프스가스',
#        '옥시싹싹 락스로싹 세제로싹', '유한락스 레귤러', '유한락스 후레쉬', '다우니 고농축 블루튤립과 달콤한 라일락',
#        '샤프란 코튼 앤 크림', '쉐리 후레쉬 시트 카밍라벤더', '피죤 용기 옐로미모사', '샤프란 케어 상쾌한 향',
#        '페브리즈 깨끗한 무향(370)', '페브리즈 깨끗한 무향(900)', '무균무때(욕실용)', '옥시싹싹(욕실용)',
#        '홈스타 곰팡이 싹', '비트(단품)', '비트(묶음)', '테크(단품)', '파워크린',
#        '퍼실 액체세제 드럼용 2.7L', '퍼실 액체세제 일반용 2.7L', '퍼펙트', '퍼펙트 하나로 리필',
#        '물먹는 하마 옷장용', '물먹는하마 슬림', '물먹는하마 신발용', '물먹는하마 참숯',
#        '홈스타 제습과 방충을 한번에', '3M후레쉬백', '롯데팩', '뽑아쓰는 크린백', '지퍼락 지퍼백(중)',
#        '크린백', '크린지퍼백', '후레시지퍼백(소)', 'CJ 참그린 ', '세이프 유기농 발아현미 리필',
#        '자연퐁 솔잎향 세균설거지(용기)', '항균트리오', '깨끗한나라 키친타올', '깨끗한나라그린티', '디럭스키친타올',
#        '배니시 옥시크린 O2액션', '비트 O2 살균표백제', '테크표백젤', '대한웰빙호일 15m*25m',
#        '롯데호일(25cm x 30m)', '롯데호일(30cm x 30m) ', '쿠킹호일(20cm x 30m)(삼아)',
#        '쿠킹호일(25cm x 30m)(대한) ', '쿠킹호일(25cm x 30m)(삼아)', 'BYC 데오니아 남러닝',
#        'BYC화이트러닝', 'BYC화이트반팔러닝', 'TRY 후레쉬남러닝*3매', 'TRY 후레쉬남티셔츠*3매',
#        'TRY남러닝*5매', 'TRY바이오러닝', 'TRY바이오반팔러닝', 'TRY반팔러닝*5매',
#        '제이디 100수 반팔러닝', '제이디 100수런닝 ', '제이디100수반팔러닝', '비너스 올풀림방지 팬티 스타킹',
#        '비비안 하이서포트 고탄력 팬티스타킹', '비비안 하이서포트 고탄력 팬티형 살구색', '까스명수 10병',
#        '까스명수(단품)', '생록천(단품)', '위청수(단품)', '박카스D', '박카스F 10병', '박카스F(단품)',
#        '삼성구론산D 10병', '영진구론산G 10병', '타우스액 10병', '깨끗한나라 미용티슈',
#        '잘풀리는집 보습미용티슈', '코디 뉴 플라워 미용티슈', '크리넥스 알로에플러스 미용티슈', '가그린 레귤러',
#        '리스테린 쿨민트', '깨끗한나라 벚꽃 3겹데코', '깨끗한나라 순수 3겹데코', '크리넥스데코앤소프트',
#        '깨끗한 나라(단품)', '깨끗한 나라(묶음)', '닥터 아토마일드(묶음)',
#        'AVEENO daily moisturizing bodywash active natural',
#        '뉴트로지나릴렉싱바디워시', '뉴트로지나모이스춰라이징바디워시', '도브 뷰티 너리싱 바디워시',
#        '도브 센스티브스킨 바디워시 ', '도브뷰티모이스처바디워시', '도브아쿠아바디워시', '세이 온더바디 고보습 아이리스',
#        '세이 허브 바디워시', '해피바스 로즈에센스 로맨틱 바디워시', '해피바스바디클렌저 정말촉촉한타입',
#        'Dr. ato(민감성건성피부보습)', 'JB 뉴 베드타임 로션', '그린핑거 순한자연보습 베이비로션(220ml)',
#        '그린핑거 순한자연보습 베이비로션(320ml)', '아비노베이비데일리모이스춰로션', '퓨어가닉허브로션',
#        '바디피트 볼록맞춤울트라중형', '위스퍼 리프레시 클린케어 중형날개', '좋은느낌 스키니핏 하이퍼 울트라 날개 중형',
#        '화이트 NEW시크릿홀 울트라 날개 중형', 'P&G 아이보리', '도브 뷰티바', '드봉 스위트로즈',
#        '알뜨랑비누 핑크', '해피바스 허브 라벤더 아로마 바', '데톨 오리지날 허브', '아이!깨끗해 항균폼 상큼레몬향',
#        '온더바디 핸드워시', '해피바스 항균 레몬그라스 핸드워시',
#        '뉴트로지나 Ultra Sheer Dry-Touch Sun Block',
#        '니베아 Face Sun Block Moisturizing Cream', '니베아 Fresh Sun Lotion',
#        '아비노 컨티뉴어스 프로텍션 선블럭', '페이스선블럭 화이트닝', 'iope 슈퍼바이탈 에멀젼',
#        '이자녹스 테르비나 루미에르 화이트 에멀젼', 'iope 슈퍼바이탈 소프너',
#        '이자녹스 테르비나 루미에르 화이트 소프너', 'iope 슈퍼바이탈 세럼', '이자녹스 테르비나 루미에르 화이트 세럼',
#        '더블리치 간편염색 (4G, 자연갈색)', '리엔 흑모비책크림염색', '리엔 흑모비책크림염색 자연갈색',
#        '미쟝센 샤이닝에센스크림컬러 6C(자연밤색)', '미쟝센 쉽고빠른거품염색(3N 흑갈색)', '비겐크림폼(짙은 갈색)',
#        '도브 데미지 볼륨 부스트 린스', '미장센 펄샤이닝모이스쳐 린스', '엘라스틴 맥시마이징 볼륨 컨디셔너',
#        '팬틴 바운시 볼륨케어 컨디셔닝 린스', 'PACE 6 면도날', '마하3 면도날', '익스트림3 서브제로 3날',
#        '하이드로5 면도날', '도브 데미지 볼륨 부스트 샴푸', '미장센 펄샤이닝모이스쳐 샴푸',
#        '엘라스틴 맥시마이징 볼륨 샴푸', '팬틴 바운시 볼륨케어 샴푸', 'NEW하기스 네이처메이드 남아용 대형',
#        '뉴하기스 프리미어4 남아용 대형', '2080 오리지날 블루 충치케어(단품)',
#        '2080 오리지날 블루 충치케어(묶음)', '메디안 프라그제거(단품)', '메디안 프라그제거(묶음)',
#        '메디안 후레쉬마린(묶음)', '송염치약(묶음)', '클링스 어드밴스드 클린민트(묶음)', '페리오 캐비티케어(묶음)',
#        '페리오A(단품)', '페리오A(묶음)', 'Neut.핸드크림', '니베아 SOS', '해피바스 내추럴24핸드크림'],
#       dtype=object)

# %%
li_groceries = ['소면','국수','만두','당면','두부','라면','밀가루','부침가루','빵','호떡','만쥬','스프','스페설K','콘푸로스트','콘푸라이트',
               '미역국','짜장','카레','오뚜기밥','찰진밥','햇반','우동','야채죽','단팥죽','쇠고기죽','초밥','칩포테이토','포카칩','자일리톨',
               '해태아이스쿨','돼지바','메로나','바밤바','새우깡','가나파이','몽쉘크림','초코파이','초콜렛','목캔디','아이비','참크래커',
               '마가린','7even','떠먹는불가리스','바이오거트','요플레','이오','불가리스','버터','앱솔루트','분유','프리미엄프레쉬','건강한햄',
               '비앤나','롯데햄','소시지','아메리칸후랑크','의성 마늘','우유','드빈치','치즈','슬라이스햄','샌드위치햄','김밥김','맛살',
               '꽁치','어묵','참치','고추장','간장','태양초골드','황도','된장','마요네즈','딸기잼','딸기쨈','설탕','벌꿀','꽃소금',
               '옥수수유','식용유','콩기름','식초','쌈장','참기름','케찹','해물','델몬트','오렌지','현미녹차','베지밀','두유','생막걸리',
               '우국생','HITE','오비골든라거','카스 프레쉬','비타500','비타파워','스프라이트','칠성사이터','삼다수','아이시스','워터라인',
               '참이슬','처음처럼','비락식혜','게토레이','파워에이드','포카리스웨트','순보리차','옥수수수염차','레쓰비','맥스웰 하우스',
               '맥심 티오피','칸타타','맥심모카골드','테이스터스초이스','프렌치까페','카페라떼','코카콜라','펩시콜라','카페오레','김치',
               '콩나물','단무지']

li_meat = ['삼겹살','쇠고기등심','쇠고기불고기','달걀','목초란','토종닭','알짜란']

li_necessaries = ['페리오','핸드크림','니베아','해피바스','클링스','치약','2080','샴푸','하기스','면도날','3날','린스','컨디셔너',
                 '이자녹스 테르비나','iope 슈퍼바이탈','염색','미쟝센','비겐크림폼','선블럭','뉴트로지나','핸드워시','아이!깨끗해',
                 '비누','좋은느낌','화이트 New','위스퍼','바디피트','로션','Dr.','바디워시','온더바디','AVEENO','티슈','가그린','리스테린',
                 'TRY','BYC','호일','비비안','러닝','비너스','테크','크린','후레시지퍼백','참그린','지퍼락','롯데팩','후레쉬백',
                 '키친타올','홈스타','물먹는하마',' 물먹는 하마','깨끗한나라',' 향균트리오',' 페브리즈','비트','무균무때','옥시싹싹',
                 '샤프란','락스','피죤','다우니','맥스','가스','크린랩','듀라셀','마미손']

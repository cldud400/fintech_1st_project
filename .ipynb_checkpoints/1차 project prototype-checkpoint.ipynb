# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import MySQLdb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests
from bs4 import BeautifulSoup

import re

# %%
# matplotlib 한글화

import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus'] = False

path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

# %%
df = pd.read_csv('한국소비자원 생필품 및 서비스 가격 정보_20220128.csv', encoding='ansi')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9180/4014120242.py in <module>
# ----> 1 df = pd.read_csv('한국소비자원 생필품 및 서비스 가격 정보_20220128.csv', encoding='ansi')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '한국소비자원 생필품 및 서비스 가격 정보_20220128.csv'

# %%
df.head()
# Out:
#              상품명         조사일  판매가격       판매업소   제조사 세일여부 원플러스원
# 0  머거본 꿀땅콩(135g)  2022-01-14  3600     CU(본사)   머거본    N     N
# 1  머거본 꿀땅콩(135g)  2022-01-14  2190    롯데슈퍼안양점   머거본    N     N
# 2  허니버터아몬드(210g)  2022-01-14  5990  롯데슈퍼김포전원점  길림양행    N     N
# 3  허니버터아몬드(210g)  2022-01-14  5990    롯데슈퍼길동점  길림양행    N     N
# 4  허니버터아몬드(210g)  2022-01-14  5990    롯데슈퍼구평점  길림양행    N     N

# %%
df[df['상품명'] == '허니버터아몬드(210g)'].groupby(['판매가격','판매업소']).min()
# Out:
#                             상품명         조사일   제조사 세일여부 원플러스원
# 판매가격 판매업소
# 3990 롯데슈퍼남가좌점     허니버터아몬드(210g)  2022-01-28  길림양행    N     N
#      롯데슈퍼대구각산점    허니버터아몬드(210g)  2022-01-14  길림양행    N     N
# 4950 롯데슈퍼상계7동점    허니버터아몬드(210g)  2022-01-14  길림양행    N     N
#      롯데슈퍼프리미엄서초점  허니버터아몬드(210g)  2022-01-14  길림양행    N     N
# 4990 롯데슈퍼상남점      허니버터아몬드(210g)  2022-01-14  길림양행    N     N
# ...                         ...         ...   ...  ...   ...
# 7480 이마트해운대점      허니버터아몬드(210g)  2022-01-14  길림양행  NaN   NaN
#      이마트화성봉담점     허니버터아몬드(210g)  2022-01-14  길림양행  NaN   NaN
#      이마트화정점       허니버터아몬드(210g)  2022-01-14  길림양행  NaN   NaN
#      이마트흥덕점       허니버터아몬드(210g)  2022-01-14  길림양행  NaN   NaN
# 8900 신세계백화점강남점    허니버터아몬드(210g)  2022-01-28  길림양행  NaN   NaN
#
# [597 rows x 5 columns]

# %%
df = pd.read_csv('한국소비자원 생필품 및 서비스 가격 정보_20220128.csv', encoding='cp949')

# %%
# date타임으로 변경 후 년, 월만 남기기
# df.rename(columns={'조사일':'년/월'})
df['조사일'] = df['조사일'].apply(lambda x : x[:7])
df['조사일'] = pd.to_datetime(df['조사일'])

# %%
# 제조사, 세일여부, 원플러스원 drop
# df.drop(['제조사', '세일여부', '원플러스원'], axis = 1, inplace = True)

# %%
# unique한 상품 리스트
prod_ = df['상품명'].unique()
for pro in prod_:
    print(pro)

# %%
# 용량만 분리해서 따로 칼럼으로 만들기
# 일단 보류

# %%
# 지점명을 따로 추출해서 새로운 칼럼에 추가

# %%
df['판매업소'].unique()
# Out:
# array(['CU(본사)', '롯데슈퍼안양점', '롯데슈퍼김포전원점', '롯데슈퍼길동점', '롯데슈퍼구평점', '롯데슈퍼광혜원점',
#        '롯데슈퍼교문점', '롯데슈퍼광주점', '롯데슈퍼광주도평점', '롯데슈퍼광명점', '롯데슈퍼광명소하점',
#        '롯데슈퍼공릉점', '롯데슈퍼고양원흥점', '롯데슈퍼고양풍동점', '롯데슈퍼고양식사점', '롯데슈퍼고양동산점',
#        '롯데슈퍼경주용황점', '롯데슈퍼경주동천점', '롯데슈퍼개화산점', '롯데슈퍼거제상동점', '롯데슈퍼갈월점',
#        '롯데슈퍼가락점', '이마트계양점', '롯데슈퍼G화곡점', '롯데슈퍼G홍제점', '롯데슈퍼G철원점',
#        '롯데슈퍼G춘천점', '롯데슈퍼G중동점', '롯데슈퍼G전곡점', '롯데슈퍼G은평점', '롯데슈퍼G은마점',
#        '롯데슈퍼G유진점', '이마트평촌점', '이마트자양점', '롯데슈퍼수성점', '이마트월배점', '이마트여수점',
#        '이마트울산점', '이마트춘천점', '롯데슈퍼연수점', '롯데슈퍼범서점', '롯데슈퍼시흥조남점', '롯데슈퍼시흥장곡점',
#        '롯데슈퍼시흥능곡점', '롯데슈퍼시흥은행점', '롯데슈퍼송천점', '롯데슈퍼송정점', '롯데슈퍼송양점',
#        '롯데슈퍼세류역점', '롯데슈퍼세곡점', '롯데슈퍼세교점', '롯데슈퍼성주점', '롯데슈퍼성수점', '롯데슈퍼성내점',
#        '롯데슈퍼서초3동점', '롯데슈퍼서초국제점', '롯데슈퍼서창점', '롯데슈퍼상계7동점', '롯데슈퍼상계11점',
#        '롯데슈퍼삼천포점', '롯데슈퍼산본2동점', '롯데슈퍼삼성역점', '롯데슈퍼분당이매점', '롯데슈퍼분당서현점',
#        '롯데슈퍼분당구미점', '롯데슈퍼부산화명점', '롯데슈퍼부산학장점', '롯데슈퍼부산문현점', '롯데슈퍼부산정관점',
#        '롯데슈퍼봉은사로점', '롯데슈퍼복현점', '롯데슈퍼보령동대점', '롯데슈퍼방화점', '롯데슈퍼방학점',
#        '롯데슈퍼명동점', '롯데슈퍼명지점', '롯데슈퍼망포역점', '롯데슈퍼마포대흥점', '롯데슈퍼두정2점',
#        '롯데슈퍼두암점', '롯데슈퍼동탄영천점', '롯데슈퍼동탄청계2점', '롯데슈퍼덕정점', '롯데슈퍼대치4동점',
#        '롯데슈퍼대전둔산점', '롯데슈퍼대연점', '롯데슈퍼대야2점', '롯데슈퍼대구대실점', '롯데슈퍼대구현풍점',
#        '롯데슈퍼대구고산점', '롯데슈퍼대구각산점', '롯데슈퍼당수점', '롯데슈퍼당리점', '롯데슈퍼녹양점',
#        '롯데슈퍼단구점', '롯데슈퍼남현점', '롯데슈퍼남원점', '롯데슈퍼남양주호평점', '롯데슈퍼남양주청학점',
#        '롯데슈퍼남양주별내점', '롯데슈퍼남양주마석점', '롯데슈퍼남양주도곡점', '롯데슈퍼남가좌점', '롯데슈퍼남산점',
#        '롯데슈퍼김해장유점', '롯데슈퍼용운점', '롯데슈퍼중계점', '롯데슈퍼중촌점', '롯데슈퍼중계역점',
#        '롯데슈퍼연산점', '롯데슈퍼종로평창점', '롯데슈퍼정자점', '롯데슈퍼전주평화점', '롯데슈퍼정릉점',
#        '롯데슈퍼전북대점', '롯데슈퍼전농점', '롯데슈퍼장안점', '롯데슈퍼장락점', '롯데슈퍼자곡점',
#        '롯데슈퍼잠실3동점', '롯데슈퍼인후점', '롯데슈퍼인하대점', '이마트양재점', '롯데슈퍼인천청천점',
#        '롯데슈퍼인천청라점', '롯데슈퍼인천청라2점', '롯데슈퍼인천동양점', '롯데슈퍼인천문학점', '롯데슈퍼인천고잔점',
#        '롯데슈퍼송파점', '롯데슈퍼인계점', '롯데슈퍼이문점', '롯데슈퍼은평진관2점', '롯데슈퍼율전점',
#        '롯데슈퍼위례중앙점', '이마트영등포점', '롯데슈퍼월계점', '롯데슈퍼울산매곡점', '롯데슈퍼우장산점',
#        '롯데슈퍼우만점', '롯데슈퍼용인성복점', '롯데슈퍼용인점', '롯데슈퍼용인동천점', '롯데슈퍼오산점',
#        '롯데슈퍼영월점', '롯데슈퍼연수함박점', '롯데슈퍼역촌점', '롯데슈퍼역삼3점', '롯데슈퍼여의점',
#        '롯데슈퍼엑스포점', '롯데슈퍼언남점', '롯데슈퍼양산남부점', '롯데슈퍼양산가촌2점', '롯데슈퍼양산가촌점',
#        '롯데슈퍼야탑점', '롯데슈퍼안산점', '롯데슈퍼안산본오점', '롯데슈퍼안산고잔점', '롯데슈퍼아산용화점',
#        '롯데슈퍼아산용화2점', '이마트해운대점', '롯데슈퍼쌍문점', '롯데슈퍼신천점', '롯데슈퍼신부점',
#        '롯데슈퍼신반포점', '롯데슈퍼신도림점', '롯데슈퍼신동아점', '롯데슈퍼신당점', '롯데슈퍼신가점',
#        '롯데슈퍼일산점', '롯데슈퍼이천점', '이마트신월점', '이마트만촌점', '롯데슈퍼원주점', '롯데슈퍼원효로점',
#        '롯데슈퍼장위점', '이마트상봉점', '이마트서귀포점', '이마트제주점', '이마트원주점', '이마트역삼점',
#        '이마트이수점', '롯데슈퍼수원경기대2점', '이마트용산점', '롯데슈퍼프리미엄용호점', '롯데슈퍼용인남사점',
#        '롯데슈퍼프리미엄기흥점', '롯데슈퍼포항장성점', '롯데슈퍼프리미엄황금점', '롯데슈퍼부산영도점', '롯데슈퍼반포2점',
#        '롯데슈퍼프리미엄일원점', '롯데슈퍼순천오천점', '롯데슈퍼프리미엄서초점', '롯데슈퍼광명일직점',
#        '롯데슈퍼부천옥길점', '롯데슈퍼김해진영점', '롯데슈퍼율하점', '이마트광주점', '이마트의왕점', '롯데슈퍼창천점',
#        '롯데슈퍼율량점', '롯데슈퍼삼천점', '롯데슈퍼동탄청계점', '롯데슈퍼보령점', '롯데슈퍼효자점',
#        '롯데슈퍼효자2점', '롯데슈퍼화성봉담점', '롯데슈퍼회룡역점', '롯데슈퍼홍제점', '롯데슈퍼홍은점',
#        '롯데슈퍼함양점', '롯데슈퍼한빛점', '롯데슈퍼한마음점', '롯데슈퍼프리미엄문정점', '롯데슈퍼하월곡점',
#        '롯데슈퍼프리미엄도곡점', '롯데슈퍼프리미엄공덕점', '롯데슈퍼판교점', '롯데슈퍼평창진부점', '롯데슈퍼파주금촌점',
#        '롯데슈퍼탑동3점', '롯데슈퍼코엑스점', '롯데슈퍼칠곡중리점', '롯데슈퍼청계점', '롯데슈퍼천왕점',
#        '롯데슈퍼철산점', '롯데슈퍼창천2점', '롯데슈퍼창동점', '롯데슈퍼창동2점', '롯데슈퍼진주초전2점',
#        '이마트김해점', '이마트김포한강점', '이마트김천점', '이마트금정점', '이마트군산점', '이마트구로점',
#        '이마트광산점', '이마트광명소하점', '이마트과천점', '이마트경산점', '이마트경기광주점', '이마트검단점',
#        '이마트용인점', '이마트연수점', '롯데슈퍼세종고운점', '롯데슈퍼청전점', '롯데슈퍼잠원점', '롯데슈퍼하당점',
#        '롯데슈퍼수유점', '롯데슈퍼신현점', '롯데슈퍼월성점', '롯데슈퍼풍암점', '롯데슈퍼봉선점', '롯데슈퍼영주점',
#        '롯데슈퍼태안점', '롯데슈퍼경주점', '롯데슈퍼포천일동점', '롯데슈퍼상록수점', '롯데슈퍼탑동점',
#        '롯데슈퍼새서울점', '이마트광교점', '이마트가든5점', '이마트강릉점', '이마트남원점', '이마트광명점',
#        '이마트남양주점', '이마트수원점', '이마트천안서북점', '이마트제천점', '이마트동탄점', '이마트마산점',
#        '이마트구미점', '이마트분당점', '이마트산본점', '이마트의정부점', '이마트가양점', '이마트죽전점',
#        '이마트청주점', '이마트다산점', '이마트포항점', '이마트전주점', '이마트천안점', '이마트신도림점',
#        '롯데슈퍼포항점', '이마트화정점', '롯데슈퍼상남점', '롯데슈퍼문흥점', '롯데슈퍼합천점', '롯데슈퍼백석점',
#        '롯데슈퍼분당점', '롯데슈퍼평택점', '롯데슈퍼수지점', '롯데슈퍼의정부점', '이마트미아점', '이마트둔산점',
#        '이마트흥덕점', '이마트화성봉담점', '이마트하월곡점', '이마트하남점', '이마트풍산점', '이마트포천점',
#        '이마트평택점', '이마트펜타포트점', '이마트파주운정점', '이마트통영점', '이마트킨텍스점', '이마트칠성점',
#        '이마트충주점', '이마트청계천점', '이마트천호점', '이마트천안터미널점', '이마트창원점', '이마트진주점',
#        '이마트진접점', '이마트중동점', '이마트일산점', '이마트익산점', '이마트이천점', '이마트포항이동점',
#        '이마트은평점', '이마트월계점', '이마트왕십리점', '이마트오산점', '이마트양산점', '이마트영천점',
#        '이마트연제점', '이마트여주점', '이마트여의도점', '이마트양주점', '이마트안성점', '이마트안동점',
#        '이마트아산점', '이마트신제주점', '이마트순천점', '이마트수지점', '이마트속초점', '이마트세종점',
#        '이마트성수점', '이마트성서점', '이마트성남점', '이마트서수원점', '이마트서산점', '이마트사천점',
#        '이마트상주점', '이마트사상점', '이마트봉선점', '이마트보령점', '이마트별내점', '이마트반야월점',
#        '이마트문현점', '이마트묵동점', '이마트목포점', '이마트목동점', '이마트명일점', '이마트마포점',
#        '이마트동인천점', '이마트대전터미널점', '이마트파주점', '이마트창동점', '신세계백화점센텀시티점',
#        'GS더프레시구월점', 'GS더프레시대전도마점', '이마트수색점', '이마트동해점', '이마트동백점',
#        '이마트동구미점', 'GS더프레시울산구영점', 'GS더프레시북가좌점', '(주)부산경남유통 부산점',
#        '(주)농협하나로유통 성남점', '신세계백화점강남점', '이마트수서점', '이마트보라점', 'GS더프레시성북돈암점',
#        'GS더프레시장유대청점', 'GS더프레시양산가촌점', 'GS더프레시진주신안점', 'GS더프레시김해외동점',
#        'GS더프레시도청신도시점', 'GS더프레시파주청암점', 'GS더프레시인천동춘점', 'GS더프레시시흥은계점',
#        'GS더프레시세종아름점', 'GS더프레시판교운중점', 'GS더프레시송도마스터뷰점', 'GS더프레시안양메가트리아점',
#        'GS더프레시아산둔포점', 'GS더프레시배곧신도시점', 'GS더프레시아산탕정점', 'GS더프레시수원아트리움점',
#        'GS더프레시청주율량점', 'GS더프레시동소문점', 'GS더프레시대동점', '(주)농협하나로유통 김해점',
#        '(주)충북유통', '(주)농협하나로유통 달성점', '(주)농협하나로유통 광주점', 'GS더프레시경주현곡점',
#        'GS더프레시천안두정점', 'GS더프레시청주용담점', 'GS더프레시하남점', 'GS더프레시연수점',
#        'GS더프레시구포점', '(주)농협하나로유통 고양점', 'GS더프레시목동7점', '(주)농협하나로유통 수원점',
#        'GS더프레시도곡렉슬점', 'GS더프레시원주점', 'GS더프레시종로구기점', '이마트태백점',
#        'GS더프레시은평뉴타운점', 'GS더프레시서초점', 'GS더프레시서인천점', 'GS더프레시충주용산점',
#        'GS더프레시충주연수점', 'GS더프레시분당시범단지점', 'GS더프레시초읍점', 'GS더프레시부평산곡점',
#        'GS더프레시부암점', 'GS더프레시청주점', 'GS더프레시청주봉명점', 'GS더프레시청라라임점',
#        'GS더프레시부곡점', 'GS더프레시천안점', 'GS더프레시방이점', 'GS더프레시미래점', 'GS더프레시천안쌍용점',
#        'GS더프레시문경점', 'GS더프레시목동13점', 'GS더프레시명장점', 'GS더프레시명일점', 'GS더프레시만덕점',
#        'GS더프레시만수점', 'GS더프레시마포상암점', 'GS더프레시창원감계점', 'GS더프레시마산회원점',
#        'GS더프레시진해풍호점', 'GS더프레시마산점', 'GS더프레시진해여좌점', 'GS더프레시진해자은점',
#        'GS더프레시진천점', 'GS더프레시동두천점', 'GS더프레시진주평거점', 'GS더프레시양천신은점',
#        'GS더프레시원주혁신점', 'GS더프레시명지국제점', 'GS더프레시원동점', 'GS더프레시용인포곡점',
#        'GS더프레시동탄중앙점', 'GS더프레시용인점', 'GS더프레시홍천점', 'GS더프레시화명점', 'GS더프레시행신점',
#        'GS더프레시예산점', 'GS더프레시학익점', 'GS더프레시여의도점', 'GS더프레시하안8점',
#        'GS더프레시하남미사점', 'GS더프레시양산물금점', 'GS더프레시안성점', 'GS더프레시신탄진점',
#        'GS더프레시신주례점', 'GS더프레시신갈점', 'GS더프레시수원매탄점', 'GS더프레시시흥정왕점',
#        'GS더프레시포천점', 'GS더프레시수원망포점', 'GS더프레시토월점', 'GS더프레시송파점',
#        'GS더프레시송파위례점', 'GS더프레시송도그린워크점', 'GS더프레시송도점', 'GS더프레시속초교동점',
#        'GS더프레시칠곡왜관점', '(주)농협유통 양재점', '롯데슈퍼G복대2점', '롯데슈퍼G만수점',
#        '(주)농협유통 창동점', '신세계백화점본점', 'GS더프레시상계점', '(주)농협하나로유통 울산점',
#        'GS더프레시본리점', 'GS더프레시위례중앙점', 'GS더프레시거제신현점', 'GS더프레시거제옥포점',
#        'GS더프레시개금점', 'GS더프레시강릉포남점', 'GS더프레시강릉입암점', 'GS더프레시강남대치점',
#        '(주)농협대전유통', 'GS더프레시대전월평점', 'GS더프레시증평점', 'GS더프레시대전송강점',
#        'GS더프레시대방점', 'GS더프레시당진점', 'GS더프레시죽곡점', 'GS더프레시주례점', 'GS더프레시다대점',
#        'GS더프레시당진송악점', 'GS더프레시종로평창점', 'GS더프레시능곡점', 'GS더프레시전주호성점',
#        'GS더프레시남양주별내점', 'GS더프레시낙성대점', 'GS더프레시장유점', 'GS더프레시김포한강자이점',
#        'GS더프레시김포사우점', 'GS더프레시김포감정점', 'GS더프레시장유삼문점', 'GS더프레시금촌점',
#        'GS더프레시군산나운점', 'GS더프레시군포당정점', 'GS더프레시잠원점', 'GS더프레시잠실파크리오점',
#        'GS더프레시잠실점', 'GS더프레시잠실장미점', 'GS더프레시인천삼산점', 'GS더프레시의정부민락점',
#        'GS더프레시인천부개점', 'GS더프레시의왕점', 'GS더프레시의왕오전점', '롯데슈퍼G운정점', '롯데슈퍼G오남2점',
#        '롯데슈퍼G수지점', '롯데슈퍼G신곡점', '롯데슈퍼G속초조양점', '롯데슈퍼G소사점', '롯데슈퍼G속초점',
#        '롯데슈퍼G부곡점', '롯데슈퍼G복대점', '롯데슈퍼G보라점', '롯데슈퍼G목동점', '롯데슈퍼G방배점',
#        '롯데슈퍼G대림점', '롯데슈퍼G마포점', '롯데슈퍼G내손점', '롯데슈퍼G강서점', '롯데슈퍼G고양삼송점',
#        '세븐일레븐(본사)', '현대백화점천호점', 'GS25(본사)', '롯데슈퍼G구리갈매점', '신세계백화점죽전점',
#        '신세계백화점영등포점', '현대백화점목동점'], dtype=object)

# %%
li_brands = ['CU','롯데슈퍼','이마트','(주)부산경남유통','GS더프래시','세븐일레븐','GS25','GS수퍼마켓','홈플러스',
         '롯데마트','신세계백화점','현대백화점','롯데백화점','농협']
li_groceries = ['소면','국수','만두','당면','두부','라면','밀가루','부침가루','빵','호떡','만쥬','스프','스페설K','콘푸로스트','콘푸라이트',
               '미역국','짜장','카레','오뚜기밥','찰진밥','햇반','우동','야채죽','단팥죽','쇠고기죽','초밥','칩포테이토','포카칩','자일리톨',
               '해태아이스쿨','돼지바','메로나','바밤바','새우깡','가나파이','몽쉘크림','초코파이','초콜렛','목캔디','아이비','참크래커',
               '마가린','7even','떠먹는불가리스','바이오거트','요플레','이오','불가리스','버터','앱솔루트','분유','프리미엄프레쉬','건강한햄',
               '비앤나','롯데햄','소시지','아메리칸후랑크','의성 마늘','우유','드빈치','치즈','슬라이스햄','샌드위치햄','김밥김','맛살',
               '꽁치','어묵','참치','고추장','간장','태양초골드','황도','된장','마요네즈','딸기잼','딸기쨈','설탕','벌꿀','꽃소금',
               '옥수수유','식용유','콩기름','식초','쌈장','참기름','케찹','해물','델몬트','오렌지','현미녹차','베지밀','두유','생막걸리',
               '우국생','HITE','오비골든라거','카스 프레쉬','비타500','비타파워','스프라이트','칠성사이터','삼다수','아이시스','워터라인',
               '참이슬','처음처럼','비락식혜','게토레이','파워에이드','포카리스웨트','순보리차','옥수수수염차','레쓰비','맥스웰 하우스',
               '맥심 티오피','칸타타','맥심모카골드','테이스터스초이스','프렌치까페','카페라떼','코카콜라','펩시콜라','카페오레','김치',
               '콩나물','단무지','월드콘','박카스','배추','부라보콘','구론산','스타벅스','양파','참붕어','몽쉘','칠성사이다','풀무원','스페셜K',
               '네스카페','오리온','감자','고구마','버섯','애호박','대파','막걸리','토스트','남양','당근','동서','마늘','시금치','엔젤리너스','오뚜기',
               '컨피던스','풋고추','샘표','오이','국내산','고등어','롯데','오징어','백설','삼립','씨그램','레드불','비비고','떡','몬스터','탄산수','청정원',
                '오리온','켈로그','팔도','하선정','해태','엔제리너스','스팸','들기름','트레비','굴소스','땅콩','아몬드','적상추','쪽파','생강','양반',
                '투게더','줄기 없는 무', '깻잎','가지', '카스','오비라거','자유시간','하이트','핫브레이크']

li_meat = ['삼겹살','쇠고기등심','쇠고기불고기','달걀','목초란','토종닭','알짜란','백숙','특란','갈치','삼치','참조기','건강란',
          '쇠고기 등심','쇠고기 불고기','돼지고기 목살','부세']

li_necessaries = ['페리오','핸드크림','니베아','해피바스','클링스','치약','2080','샴푸','하기스','면도날','3날','린스','컨디셔너',
                 '이자녹스 테르비나','iope 슈퍼바이탈','염색','미쟝센','비겐크림폼','선블럭','뉴트로지나','핸드워시','아이!깨끗해',
                 '비누','좋은느낌','화이트 New','위스퍼','바디피트','로션','Dr.','바디워시','온더바디','AVEENO','티슈','가그린','리스테린',
                 'TRY','BYC','호일','비비안','러닝','비너스','테크','크린','후레시지퍼백','참그린','지퍼락','롯데팩','후레쉬백',
                 '키친타올','홈스타','물먹는하마','물먹는 하마','깨끗한나라','항균트리오','페브리즈','비트','무균무때','옥시싹싹',
                 '샤프란','락스','피죤','다우니','맥스','가스','크린랩','듀라셀','마미손','위청수','타우스액','까스명수',
                 '데톨','후레쉬랩','화이트','향균트리오','데톨','메디안','롯데랩','메디안','벡셀','드봉 스위트로즈','도브','깨끗한 나라','P&G',
                  '퍼실','크리넥스','제이디','퍼펙트','에너자이저','닥터','생록천','쉐리','고무장갑','자연퐁','세이프',
                 '스파크','어드밴스 캐비티','알프스디','보솜이','표백제','세정제','팬티','컴배트',
                 '홈키파','에프킬라','임페리얼','챕스틱','클린앤클리어','오랄비','향균 트리오']

# %%
def find_brand(x):
    global brands
    for bra in brands:
        if bra in x:
            return bra
    return np.nan

def categorization(x):
    global li_meat
    global li_groceries
    global li_necessaries
    global else_li
    if x == '무':
        return '식품'
    for meat in li_meat:
        if meat in x:
            return '축산물'
    for gro in li_groceries:
        if gro in x:
            return '식품'
    for nec in li_necessaries:
        if nec in x:
            return '생필품'
    return np.nan

def find_prod(x):
    global prod_li
    if x in prod_li:
        return x
    return np.nan

def brand_prod(x):
    global prod_li
    global brands
    global df
    for bra in brands:
        for pro in df[df['브랜드'] == bra]['상품명']:
            if pro in prod_li:
                return x

# %%
df_2014_1 = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터/2014년 1월 가격데이터.csv', encoding='ansi')

# %%
uni_ =  df_2014_1.상품명.unique()

# %%
df_2014_1['브랜드'] = np.nan

# %%
df_2014_1 ['브랜드'] = df_2014_1['판매업소'].apply(find_brand)

# %%
df_2014_1 ['상품명'].unique()
# Out:
# array(['서울우유 체다슬라이스치즈(400g)', '식빵위의네모', '오뚜기황도', '해찬들 재래식 된장 ', '백설국내콩기름',
#        '진한케찹(대상)', '포카칩 오리지날', '돼지바(단품)', '월드콘XQ(단품)', '가나파이 오리지날 12개입',
#        'HITE(6캔)', '스프라이트', '참이슬 후레쉬', '백설부침가루(1kg)', '백설 미역국',
#        '3분 쇠고기 짜장', '국내산 목초를 먹고자란 건강한 닭이 낳은 달걀(15구)', '7even(4개묶음)',
#        '진간장 금F3', '오뚜기카레 순한맛', '맛선생 해물', '참크래커', '칠성사이다',
#        '국산콩두부(찌개용)(풀무원)', '켈로그 콘푸로스트(600g)', '맛있는 미역국', '뉴트로지나릴렉싱바디워시',
#        '위스퍼 리프레시 클린케어 중형날개', '물먹는하마 슬림', '물먹는하마 신발용',
#        '떠먹는불가리스 딸기 오리지날(4개묶음)', '임페리얼분유XO 1단계(800g)', '참작 참잘만든 슬라이스햄',
#        '딸기잼 ', '쇠고기등심(1등급)', '대상 사과식초', '달콤한 삼육두유 B', '오비골든라거 6캔',
#        '삼다수(500ml, 묶음)', '참이슬 클래식', '옥수수수염차', '테이스터스초이스 오리지날',
#        '악마의유혹 프렌치 카페오레', '잘풀리는집 보습미용티슈', '리스테린 쿨민트',
#        '해피바스 로즈에센스 로맨틱 바디워시', '퓨어가닉허브로션', '아이!깨끗해 항균폼 상큼레몬향',
#        '니베아 Face Sun Block Moisturizing Cream', '미쟝센 쉽고빠른거품염색(3N 흑갈색)',
#        '미장센 펄샤이닝모이스쳐 샴푸', '메디안 후레쉬마린(묶음)', '페브리즈 깨끗한 무향(900)',
#        '퍼실 액체세제 드럼용 2.7L', '크린백', 'CJ 참그린 ', '세이프 유기농 발아현미 리필',
#        '비트 O2 살균표백제', '롯데호일(30cm x 30m) ', '고소한국산콩두부(부침용)(대상)',
#        '순창 오리지널 우리쌀 찰고추장 ', '샘표황도', '칩포테이토 오리지날', '델몬트 스카시플러스 100',
#        '동서현미녹차 100포', '삼다수(2L)', '동서 순보리차', '칸타타 원두커피 프리미엄 블렌드(275ml)',
#        '크린랩(22cm x 50m)', '펩시콜라(1.5L)', '아비노베이비데일리모이스춰로션', '샘표소면(1.1kg)',
#        '생야채돼지고기물만두(400g*2봉)', '오뚜기 크림스프', '맛있는오뚜기밥(6개입) ', '맛있는오뚜기밥(단품)',
#        '목초란 10구', '프레시안 샌드위치햄', '오뚜기 사과식초', '청정원 순창 쌈장', '찬마루 김밥단무지', '무',
#        'CJ하선정 포기김치(2.0kg)', '삼다수(500ml)', '맥스웰 하우스 오리지날(175ml)',
#        'JB 뉴 베드타임 로션', '물먹는하마 참숯', '배니시 옥시크린 O2액션', '쇠고기등심(1+등급)',
#        '쇠고기불고기(1등급)', '생야채물만두(700g)', 'CJ햇당면 ', '풀무원 새콤달콤 유부(330g)',
#        '김밥김', '양반 구운 김밥김', '동원 꽁치', '오리지널 요플레(4개묶음)', '백설 하얀설탕', '백설꽃소금',
#        '제일제면소 소면', '미닛메이드 오리지날 오렌지 100', '국순당 우국생', '비락식혜',
#        '도브 센스티브스킨 바디워시 ', '도브 뷰티바', '니베아 Fresh Sun Lotion', '삼양라면 5개입',
#        '풀무원 생 가쓰오 우동', '새콤달콤 간편한 유부초밥 박사(160g*2)',
#        '듀라셀 울트라 파워체크 AA*2입(피엔지)', '쉐리 후레쉬 시트 카밍라벤더', '페브리즈 깨끗한 무향(370)',
#        '무균무때(욕실용)', '옥시싹싹(욕실용)', '오뚜기파운드마가린(450g)', '이오 20s (3개묶음)',
#        '무가염버터(450g)', '남양유업 맛있는우유GT(1000ml)', '숨쉬는콩된장 구수한맛',
#        '고소한참기름(오뚜기)', '참진한참기름(해표)', '토마토케찹(오뚜기)', '비타500(묶음)', '비타파워',
#        '파워에이드 마운틴블라스트(600ml)', '레쓰비 마일드(175ml)', '코카콜라(1.5L)',
#        '깨끗한나라 순수 3겹데코', '크리넥스데코앤소프트', '그린핑거 순한자연보습 베이비로션(320ml)',
#        '엘라스틴 맥시마이징 볼륨 컨디셔너', 'PACE 6 면도날', '팬틴 바운시 볼륨케어 샴푸', '홈스타 곰팡이 싹',
#        '디럭스키친타올', '맥심 티오피 마스터블렌드(275ml)', '청정원 우리쌀 크림스프',
#        '동원 양반 국산100% 쇠고기죽', '프레시안삼호부산어묵', '생야채 유부초밥(380g)',
#        '페리오 캐비티케어(묶음)', '퍼실 액체세제 일반용 2.7L', '3M후레쉬백', '스페셜K 오리지널(480g)',
#        '자연의 시작 불가리스 사과 (4개묶음)', '서울우유 흰우유(1000ml)', '삼다수(2L, 묶음)',
#        '해찬들 우리쌀태양초골드', '새우깡 ', '부라보콘(단품) 화이트바닐라', '화이트 NEW시크릿홀 울트라 날개 중형',
#        '뉴하기스 프리미어4 남아용 대형', '벡셀AA*2입', '크린랩_고무장갑(중) (묶음)',
#        '맥스 CRV 폭발방지 부탄가스', '알프스가스', '롯데비앤나(400g)', '목우촌 주부9단 소시지(500g)',
#        '롯데슬라이스햄', '동서벌꿀', '하선정 숯 김밥단무지', '종가집 풍부한 포기김치(1.9kg)', '해태아이스쿨',
#        '게토레이 레몬', '후레쉬랩(25cm x 50m)(3M)', '물먹는 하마 옷장용', '고소한골드마요네즈(오뚜기)',
#        '오뚜기식용유(콩100%)', '좋은느낌 스키니핏 하이퍼 울트라 날개 중형', '하이드로5 면도날',
#        '마일드참치(묶음)', '옥수수 마가린(200g)', '매일유업 뼈로가는 칼슘치즈(270g)', '프렌치까페믹스',
#        '해찬들 사계절 쌈장', '양파', '국화빵 수(단품)', '참붕어 싸만코(묶음)', '아이비',
#        '뼈로가는 칼슘두유 담백한맛', '3분 쇠고기 카레', '햇반(엄마가해주신밥, 6+2개입)',
#        '마니커_국내산 토종닭 1050g 팩', '쇠고기불고기(1+등급)', '샘표 김치찌개용 꽁치',
#        'I cant believe(60%) 저지방마가린(212.5g*2개)', 'CJ 더 건강한햄 그릴후랑크(350g)',
#        '해표 순창 궁 발아콩 12가지 양념쌈장', '진한참기름(CJ)', '배추',
#        '2080 오리지날 블루 충치케어(묶음)', '해피바스 내추럴24핸드크림', '순창재래식안심생된장 ',
#        '서울장수생막걸리', '아이시스(2L)', '워터라인', '비타500(단품)', '옛날국수소면',
#        '큐원 영양강화밀가루(1kg)', '찰토스트식빵', '행복한콩 제주산콩 친환경콩나물', '롯데목캔디 허브',
#        '대림게맛살큰잔치', '매일바이오거트(4개묶음)', '고소한마요네즈(대상)', '맑고신선한옥수수유',
#        '클링스 어드밴스드 클린민트(묶음)', '다우니 고농축 블루튤립과 달콤한 라일락', '오뚜기 꽁치',
#        '더블리치 간편염색 (4G, 자연갈색)', '비겐크림폼(짙은 갈색)', '자연퐁 솔잎향 세균설거지(용기)',
#        '쿠킹호일(25cm x 30m)(대한) ', '신라면 5개입', '복음자리 딸기쨈', '옥시싹싹 락스로싹 세제로싹',
#        '비트(단품)', '삼성구론산D 10병', '초코파이 18개입', '마하3 면도날', '보노콘스프',
#        '에너자이저AA*2입', '돼지고기삼겹살', '국순당 생막걸리', '스타벅스 커피라떼', '부드러운숙식빵',
#        '하림 자연실록백숙 830g', '생야채돼지고기물만두(650g+200g)', '데톨 오리지날 허브', '오뚜기 야채죽',
#        '청정원 야채죽', '남양유업 드빈치(300g)', 'NEW하기스 네이처메이드 남아용 대형', 'Neut.핸드크림',
#        '테크(단품)', '퍼펙트 하나로 리필', '프리미엄 산양분유 1단계(800g)',
#        '매일우유 오리지널(ESL)(1000ml)', '국산아작아작콩나물', '남양유업 드빈치(200g)',
#        '백설 국내산 사과식초', '돼지바(묶음)', '센쿡찰진밥(3개입)', '프레시안 주부초밥왕(320g)',
#        '메로나(묶음)', '부라보콘 5개입 화이트바닐라', '까스명수(단품)', '진라면(순한맛) 5개입',
#        '행복한콩 국산콩두부(찌개용)', '피죤 용기 옐로미모사', '깨끗한나라 키친타올', '위청수(단품)',
#        '박카스F(단품)', '영진구론산G 10병', '닥터 아토마일드(묶음)', '백설 중력밀가루(1kg)', '파워크린',
#        '롯데호일(25cm x 30m)', '드봉 스위트로즈', '센쿡찰진밥(단품)', '햇반(엄마가해주신밥, 단품)',
#        'CJ햇반 단팥죽', '동원참치 라이트스탠다드(단품)', '올에이 중형 고무장갑', '곰표 다목적밀가루(1kg)',
#        '포스트 콘푸라이트(600g)', 'CJ 가쓰오 우동 4인용', 'HITE(단품)', '오비골든라거(단품)',
#        '카스 프레쉬(단품)', '해표 꽃소금', '크리넥스 알로에플러스 미용티슈', 'Dr. ato(민감성건성피부보습)',
#        '아비노 컨티뉴어스 프로텍션 선블럭', '푸드림 하얀설탕', '몽쉘 크림', '마일드참치(단품)',
#        '웰빙 다시다 산들애 국내산해물', '달콤한 베지밀 비', '가그린 레귤러', '오뚜기부침가루(1kg)',
#        '대림오양맛살', '사조 꽁치', '햇살담은 자연숙성진간장', '세이 온더바디 고보습 아이리스',
#        '사누끼 가쓰오 생우동', '동원양반포기김치(2.2kg)', '메로나(단품)', '가나마일드초콜렛 2개입',
#        '옛날당면', '지퍼락 지퍼백(중)', '개성 감자만두', '맛있는 옛날 꿀호떡',
#        '서울우유 체다슬라이스치즈(200g)', '큐원 하얀설탕', '하림 토종닭백숙(1050g)',
#        '동원참치 라이트스탠다드(묶음)', '올리브유저지방 마가린(200g)', '송염치약(묶음)', '페이스선블럭 화이트닝',
#        '1964 정통 크림빵', '설록현미녹차 100포', '카스 프레쉬 6캔', '해피바스 허브 라벤더 아로마 바',
#        '미장센 펄샤이닝모이스쳐 린스', '도브 데미지 볼륨 부스트 샴푸', '엘라스틴 맥시마이징 볼륨 샴푸',
#        '유한락스 레귤러', '포카리스웨트', '가나마일드초콜렛(단품)', '도브 데미지 볼륨 부스트 린스',
#        '니베아 SOS', '알짜란(15구)', '바밤바(묶음)', '아이시스(500ml)', '도브 뷰티 너리싱 바디워시',
#        '주부초밥짱(480g)', '유한락스 후레쉬', '동원복숭아(황도) 슬라이스', '맥스웰 하우스 오리지날',
#        '듀라셀 AA *4입', '크린랩(30cm x 50m)', '처음처럼', '마미손_고무장갑(중) (단품)',
#        '샤프란 케어 상쾌한 향', '행복한콩 깊은바다두부(부침용)(CJ)', '매일유업 뼈로가는 칼슘치즈(180g)',
#        '맥심모카골드', '매일 카페라떼 마일드', '리엔 흑모비책크림염색 자연갈색', '사양벌꿀',
#        '팬틴 바운시 볼륨케어 컨디셔닝 린스', '샤프란 코튼 앤 크림', '뽑아쓰는 크린백', '국화빵 수(묶음)',
#        '월드콘XQ 5개입', '의성 마늘 프랑크(350g)', '썬 부탄가스', '약간매운맛 카레', '센쿡찰진밥(6개입)',
#        '맑고신선한해표식용유', '참붕어 싸만코(단품)',
#        '뉴트로지나 Ultra Sheer Dry-Touch Sun Block', '테크표백젤', '오리지널 단팥빵',
#        '한입가득 밤형만쥬', '대림선어묵 부산어묵', '마미손_고무장갑(중) (묶음)',
#        '듀라셀 울트라 파워체크 AAA*2입', '쿠킹호일(20cm x 30m)(삼아)', '생록천(단품)',
#        '자일리톨 애플민트', '쿠킹호일(25cm x 30m)(삼아)', 'iope 슈퍼바이탈 에멀젼', '항균트리오',
#        '싱싱맛살', '해피바스 항균 레몬그라스 핸드워시', '타우스액 10병', '볶음 짜장',
#        '미쟝센 샤이닝에센스크림컬러 6C(자연밤색)', '박카스D', '햇바삭김 김밥김', '알뜨랑비누 핑크',
#        '앱솔루트 명작 1단계(800g)', '모닝버터(해바라기유)(200g)', '바디피트 볼록맞춤울트라중형',
#        'iope 슈퍼바이탈 소프너', '2080 오리지날 블루 충치케어(단품)', 'iope 슈퍼바이탈 세럼',
#        '대한웰빙호일 15m*25m', '크린지퍼백', '바밤바(단품)', '홈스타 제습과 방충을 한번에',
#        '엔제리너스 카페라떼', '사조참치마일드(묶음)', '박카스F 10병', '자일리톨', 'TRY 후레쉬남러닝*3매',
#        '제이디 100수 반팔러닝', '비너스 올풀림방지 팬티 스타킹', 'BYC 데오니아 남러닝', '제이디 100수런닝 ',
#        '비비안 하이서포트 고탄력 팬티스타킹', 'TRY 후레쉬남티셔츠*3매'], dtype=object)

# %%
for year in range(2014, 2015):
    df_year = pd.DataFrame()
    for month in range(1,13):
        df = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터/{}년 {}월 가격데이터.csv'.format(year,month), encoding='ansi')
        try:
            df.drop('제조사', axis = 1, inplace=True)
        except:
            pass
        try:
            df.drop('세일여부', axis = 1, inplace=True)
        except:
            pass
        try:
            df.drop('원 플러스 원', axis = 1, inplace=True)
        except:
            pass
        try:
            df.drop('1+1', axis = 1, inplace=True)
        except:
            pass
        
        df['브랜드'] = df['판매업소'].apply(find_brand)
        df.dropna(how = 'any', inplace = True)
        df['상품명'] = df.상품명.astype('category')
        df['브랜드'] = df.브랜드.astype('category')
        df['분류'] = df.상품명.apply(categorization)
        df['분류'] = df.분류.astype('category')
        df['조사일'] = '{}-{}'.format(year,month)
#         df['조사일'] = pd.to_datetime(df.조사일)
#         df.set_index('브랜드', inplace = True)
        grouped = df.groupby(['조사일','브랜드','분류']).판매가격.mean()
        temp = grouped.unstack().reset_index()
        temp.to_csv('./avg_data/{}년{}월 평균.csv'.format(year,month), encoding='ansi')

# %%
df = pd.read_csv('./avg_data/2014년1월 평균.csv', index_col = 2, encoding = 'ansi')
for year in range(2014, 2022):
    for month in range(1,13):
        if year == 2014 and month == 1:
            continue
        temp = pd.read_csv('./avg_data/{}년{}월 평균.csv'.format(year,month), index_col = 2, encoding = 'ansi')
        df = df.append(temp)

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df['조사일'] = pd.to_datetime(df.조사일)

# %%
df = df.sort_values('조사일')

# %%
df = df.fillna(method='ffill')

# %%
df.index
# Out:
# Index(['CU', '홈플러스', '현대백화점', '이마트', '세븐일레븐', '롯데슈퍼', '신세계백화점', '롯데마트', '농협',
#        'GS수퍼마켓',
#        ...
#        '(주)부산경남유통', 'CU', 'GS25', '농협', '롯데마트', '롯데백화점', '롯데슈퍼', '세븐일레븐',
#        '신세계백화점', '현대백화점'],
#       dtype='object', name='브랜드', length=1106)

# %%
df.loc['이마트']
# Out:
#            조사일           생필품           식품          축산물
# 브랜드
# 이마트 2014-01-01  12518.887224  4610.475516  5864.454545
# 이마트 2014-02-01  13097.357544  4765.840569  5387.127660
# 이마트 2014-03-01  12544.666750  4523.508317  4820.000000
# 이마트 2014-04-01  11962.463394  4370.748453  5598.333333
# 이마트 2014-05-01  10003.967080  4142.843256  5675.633803
# ..         ...           ...          ...          ...
# 이마트 2021-08-01   8438.541146  4575.460577  7729.469298
# 이마트 2021-09-01   8563.460810  4549.382611  9684.484848
# 이마트 2021-10-01   8565.803686  4421.483365  9585.510843
# 이마트 2021-11-01   8399.638783  4613.537225  8895.745152
# 이마트 2021-12-01   8853.341040  4504.991792  7892.521739
#
# [96 rows x 4 columns]

# %%
for i in df.index.unique()[:1]:
    df.loc[i].plot()

# %%
# 생필품도 리스트를 만들어야할꺼같음
# 식품 리스트 확장
# df를 브랜드별로 만들어 저장
temp['조사일']
# Out:
# 0     2014-12
# 1     2014-12
# 2     2014-12
# 3     2014-12
# 4     2014-12
# 5     2014-12
# 6     2014-12
# 7     2014-12
# 8     2014-12
# 9     2014-12
# 10    2014-12
# 11    2014-12
# Name: 조사일, dtype: object

# %%
df_2014_1 = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터/2014년 1월 가격데이터.csv', encoding='ansi')
prod_li = df_2014_1['상품명'].unique()
prod_li
# Out:
# 384

# %%
# 2014년부터 2021년까지 존재하는 품목만 리스트에 저장
df_2014_1 = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터/2014년 1월 가격데이터.csv', encoding='ansi')
prod_li = df_2014_1['상품명'].unique()
prod_li

for year in range(2014, 2022):
    df_year = pd.DataFrame()
    for month in range(1,13):
        df = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터/{}년 {}월 가격데이터.csv'.format(year,month), encoding='ansi')
        prod_li = np.intersect1d(prod_li, df.상품명.unique())
        print(year, end = ' ')
    print()
print('end')
# Out:
# 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014
# 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015
# 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016
# 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017
# 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018
# 2019 2019 2019 2019 2019 2019 2019 2019 2019 2019 2019 2019
# 2020 2020 2020 2020 2020 2020 2020 2020 2020 2020 2020 2020
# 2021 2021 2021 2021 2021 2021 2021 2021 2021 2021 2021 2021
# end

# %%
prod_li
# Out:
# Series([], Name: 상품명, dtype: object)

# %%
# prod_li에 존재하는 품목만 남기고 전처리해서 저장
for year in range(2014, 2022):
    df_year = pd.DataFrame()
    for month in range(1,13):
        df = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터/{}년 {}월 가격데이터.csv'.format(year,month), encoding='ansi')
        try:
            df.drop('제조사', axis = 1, inplace=True)
        except:
            pass
        try:
            df.drop('세일여부', axis = 1, inplace=True)
        except:
            pass
        try:
            df.drop('원 플러스 원', axis = 1, inplace=True)
        except:
            pass
        try:
            df.drop('1+1', axis = 1, inplace=True)
        except:
            pass
        df['브랜드'] = df['판매업소'].apply(find_brand)
#         df['상품명'] = df['상품명'].apply(find_prod)
        df.dropna(how = 'any', inplace = True)
        df['상품명'] = df.상품명.astype('category')
        df['브랜드'] = df.브랜드.astype('category')
        df['분류'] = df.상품명.apply(categorization)
        df['분류'] = df.분류.astype('category')
        df['조사일'] = '{}-{}'.format(year,month)
# #         df['조사일'] = pd.to_datetime(df.조사일)
# #         df.set_index('브랜드', inplace = True)
#         grouped = df.groupby(['조사일','브랜드','분류']).판매가격.mean()
#         temp = grouped.unstack().reset_index()
#         temp.to_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/{}년{}월 평균.csv'.format(year,month), encoding='ansi') 
        df.to_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/{}년{}월 데이터.csv'.format(year,month), encoding='ansi')
#         prod_li = np.intersect1d(prod_li, df.상품명.unique())
        print(year, end = ' ')
    print()
print('end')
# Out:
# 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014
# 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015
# 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016
# 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017
# 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018
# 2019 2019 2019 2019 2019 2019 2019 2019 2019 2019 2019 2019
# 2020 2020 2020 2020 2020 2020 2020 2020 2020 2020 2020 2020
# 2021 2021 2021 2021 2021 2021 2021 2021 2021 2021 2021 2021
# end

# %%
# 2014년부터 2021년까지 존재하는 품목만 리스트에 저장
df_2014_1 = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/2014년1월 데이터.csv', encoding='ansi')
prod_li = df_2014_1.groupby('브랜드')['상품명'].unique()
prod_li['CU']
# Out:
# array(['물먹는 하마 옷장용', '옛날국수소면', '센쿡찰진밥(단품)', '햇반(엄마가해주신밥, 6+2개입)',
#        '프레시안삼호부산어묵', '마일드참치(단품)', '마일드참치(묶음)', '7even(4개묶음)',
#        '오리지널 요플레(4개묶음)', '참작 참잘만든 슬라이스햄', '백설 하얀설탕', '해표 꽃소금', '오뚜기 사과식초',
#        '찬마루 김밥단무지', '델몬트 스카시플러스 100', '달콤한 베지밀 비', '카스 프레쉬 6캔',
#        '삼다수(500ml)', '레쓰비 마일드(175ml)', '리스테린 쿨민트',
#        '니베아 Face Sun Block Moisturizing Cream', '썬 부탄가스', '옛날당면',
#        '삼양라면 5개입', '신라면 5개입', '동원 양반 국산100% 쇠고기죽', '오뚜기 꽁치', '샘표황도',
#        '고소한참기름(오뚜기)', '토마토케찹(오뚜기)', '돼지바(단품)', '바밤바(단품)', '새우깡 ',
#        '동서현미녹차 100포', '국순당 생막걸리', '위스퍼 리프레시 클린케어 중형날개', '페이스선블럭 화이트닝',
#        '듀라셀 울트라 파워체크 AAA*2입', '에너자이저AA*2입', '페브리즈 깨끗한 무향(370)', '크린백',
#        '오뚜기 크림스프', '이오 20s (3개묶음)', '서울우유 체다슬라이스치즈(200g)', '맛선생 해물',
#        '월드콘XQ(단품)', 'HITE(6캔)', '오비골든라거 6캔', '비타파워', '참이슬 후레쉬', '처음처럼',
#        '포카리스웨트', '아이!깨끗해 항균폼 상큼레몬향', '벡셀AA*2입', '맥스 CRV 폭발방지 부탄가스',
#        '지퍼락 지퍼백(중)', '진라면(순한맛) 5개입', '햇반(엄마가해주신밥, 단품)', '사누끼 가쓰오 생우동',
#        '롯데비앤나(400g)', '서울우유 흰우유(1000ml)', '남양유업 드빈치(300g)', '프레시안 샌드위치햄',
#        '오뚜기황도', '국화빵 수(단품)', '뼈로가는 칼슘두유 담백한맛', '비타500(묶음)', '칠성사이다',
#        '비락식혜', '악마의유혹 프렌치 카페오레', '코카콜라(1.5L)', '가그린 레귤러', '크리넥스데코앤소프트',
#        '듀라셀 AA *4입', '물먹는하마 참숯', '배니시 옥시크린 O2액션', '맛있는오뚜기밥(6개입) ',
#        '양반 구운 김밥김', '동원 꽁치', '자연의 시작 불가리스 사과 (4개묶음)', '롯데슬라이스햄', '식빵위의네모',
#        '딸기잼 ', '백설국내콩기름', '포카칩 오리지날', '해태아이스쿨', '부라보콘(단품) 화이트바닐라',
#        '가나마일드초콜렛(단품)', '아이시스(2L)', '스타벅스 커피라떼', '펩시콜라(1.5L)', '알프스가스',
#        '옥시싹싹(욕실용)', '생야채돼지고기물만두(400g*2봉)', '백설 중력밀가루(1kg)',
#        '스페셜K 오리지널(480g)', '포스트 콘푸라이트(600g)', '맛있는 미역국', '3분 쇠고기 카레',
#        '약간매운맛 카레', '맛있는오뚜기밥(단품)', '오뚜기 야채죽', '프레시안 주부초밥왕(320g)', '김밥김',
#        '샘표 김치찌개용 꽁치', '오뚜기파운드마가린(450g)', '남양유업 맛있는우유GT(1000ml)',
#        '매일유업 뼈로가는 칼슘치즈(180g)', '동서벌꿀', '청정원 순창 쌈장', '해찬들 사계절 쌈장',
#        '웰빙 다시다 산들애 국내산해물', '칩포테이토 오리지날', '메로나(단품)', '가나마일드초콜렛 2개입',
#        '미닛메이드 오리지날 오렌지 100', '국순당 우국생', 'HITE(단품)', '오비골든라거(단품)',
#        '카스 프레쉬(단품)', '파워에이드 마운틴블라스트(600ml)', '동서 순보리차',
#        '맥스웰 하우스 오리지날(175ml)', '맥심모카골드', '도브 뷰티바', '송염치약(묶음)', '홈스타 곰팡이 싹',
#        '박카스F 10병', '박카스F(단품)', '영진구론산G 10병', '행복한콩 국산콩두부(찌개용)', '보노콘스프',
#        '켈로그 콘푸로스트(600g)', '3분 쇠고기 짜장', 'CJ 가쓰오 우동 4인용', '풀무원 생 가쓰오 우동',
#        '청정원 야채죽', '떠먹는불가리스 딸기 오리지날(4개묶음)', 'CJ 더 건강한햄 그릴후랑크(350g)',
#        '의성 마늘 프랑크(350g)', '서울장수생막걸리', '스프라이트', '삼다수(2L, 묶음)',
#        '아이시스(500ml)', '워터라인', '게토레이 레몬', '옥수수수염차', '맥심 티오피 마스터블렌드(275ml)',
#        '칸타타 원두커피 프리미엄 블렌드(275ml)', '매일 카페라떼 마일드', 'JB 뉴 베드타임 로션',
#        '좋은느낌 스키니핏 하이퍼 울트라 날개 중형', '미쟝센 쉽고빠른거품염색(3N 흑갈색)',
#        '뉴하기스 프리미어4 남아용 대형', '2080 오리지날 블루 충치케어(단품)',
#        '2080 오리지날 블루 충치케어(묶음)', '해피바스 내추럴24핸드크림',
#        '듀라셀 울트라 파워체크 AA*2입(피엔지)', '까스명수(단품)', '위청수(단품)', '백설부침가루(1kg)',
#        'CJ햇반 단팥죽', '풀무원 새콤달콤 유부(330g)', '국내산 목초를 먹고자란 건강한 닭이 낳은 달걀(15구)',
#        '목초란 10구', '동원참치 라이트스탠다드(단품)', '옥수수 마가린(200g)',
#        '매일우유 오리지널(ESL)(1000ml)', '진간장 금F3', '순창 오리지널 우리쌀 찰고추장 ',
#        '해찬들 재래식 된장 ', '고소한골드마요네즈(오뚜기)', '진한참기름(CJ)', '오뚜기카레 순한맛',
#        '행복한콩 제주산콩 친환경콩나물', 'CJ하선정 포기김치(2.0kg)', '롯데목캔디 허브', '비타500(단품)',
#        '삼다수(2L)', '참이슬 클래식', '세이 온더바디 고보습 아이리스', '화이트 NEW시크릿홀 울트라 날개 중형',
#        '니베아 Fresh Sun Lotion', 'Neut.핸드크림'], dtype=object)

# %%
for year in range(2014, 2022):
    df_year = pd.DataFrame()
    for month in range(1,13):
        df = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터/{}년 {}월 가격데이터.csv'.format(year,month), encoding='ansi')
        prod_li = np.intersect1d(prod_li, df.상품명.unique())
        print(year, end = ' ')
    print()
print('end')
df.groupby('브랜드')['상품명'].unique()

# %%
df_2014_1 = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/2014년1월 데이터.csv', encoding='ansi')
df[df_2014_1['브랜드'] == 'CU']['상품명']
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_13028/1308292639.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df_2014_1['브랜드'] == 'CU']['상품명']
# 1632       포스트 콘푸라이트(600g)
# 1867               맛있는 미역국
# 1868               맛있는 미역국
# 1869               맛있는 미역국
# 1870               맛있는 미역국
#                ...
# 85372    롯데호일(30cm x 30m)
# 85373    롯데호일(30cm x 30m)
# 85374    롯데호일(30cm x 30m)
# 85375    롯데호일(30cm x 30m)
# 85376    롯데호일(30cm x 30m)
# Name: 상품명, Length: 445, dtype: object

# %%
# 각 브랜드 별 상품
df_2014_1 = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/2014년1월 데이터.csv', encoding='ansi')
prod_li = df_2014_1.groupby('브랜드')['상품명'].unique()
for year in range(2014, 2022):
    for month in range(1,13):
        df = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/{}년{}월 데이터.csv'.format(year,month), encoding='ansi')
        for bra in brands:
            try:
                prod_li[bra] = np.intersect1d(prod_li[bra], df.groupby('브랜드')['상품명'].unique()[bra])
            except:
                continue 
        print(year)
    print()
print('end')

# %%
# 각 브랜드 별 상품 함수
def brand_prod(x):
    globar brands
    globar prod_li
    df[]

# %%
for year in range(2014, 2022):
    df_year = pd.DataFrame()
    for month in range(1,13):
        df = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/{}년{}월 데이터.csv'.format(year,month), encoding='ansi')
        for bra in brands:

# %%
prod_li
# Out:
# 브랜드
# CU        [동원 꽁치, 롯데슬라이스햄, 리스테린 쿨민트, 매일 카페라떼 마일드, 매일우유 오...
# GS25      [롯데슬라이스햄, 매일 카페라떼 마일드, 스타벅스 커피라떼, 악마의유혹 프렌치 카페...
# GS수퍼마켓    [3분 쇠고기 짜장, 3분 쇠고기 카레, CJ 참그린 , Dr. ato(민감성건성피...
# 농협        [CJ 더 건강한햄 그릴후랑크(350g), 고소한국산콩두부(부침용)(대상), 달콤한...
# 롯데마트                                                     []
# 롯데백화점                                                    []
# 롯데슈퍼                                                     []
# 세븐일레븐                                 [롯데슬라이스햄, 칩포테이토 오리지날]
# 신세계백화점    [대상 사과식초, 동원 꽁치, 동원참치 라이트스탠다드(묶음), 리스테린 쿨민트, 매...
# 이마트       [대한웰빙호일 15m*25m, 맑고신선한옥수수유, 맥심모카골드, 무가염버터(450g...
# 현대백화점                                                    []
# 홈플러스                                                     []
# Name: 상품명, dtype: object

# %%
# 각 브래드 별로 통계를 내서 따로 저장
df = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/2014년1월 평균.csv', index_col = 2, encoding = 'ansi')
for year in range(2014, 2022):
    for month in range(1,13):
        if year == 2014 and month == 1:
            continue
        temp = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/{}년{}월 평균.csv'.format(year,month), index_col = 2, encoding = 'ansi')
        df = df.append(temp)

# %%
# df.drop('Unnamed: 0', axis = 1, inplace = True)
df['조사일'] = pd.to_datetime(df.조사일)
df = df.sort_values('조사일')
df = df.fillna(method='ffill')

# %%
prod_li
# Out:
# array(['3M후레쉬백', 'CJ 더 건강한햄 그릴후랑크(350g)', 'CJ 참그린 ', 'Dr. ato(민감성건성피부보습)',
#        'I cant believe(60%) 저지방마가린(212.5g*2개)', 'Neut.핸드크림', 'PACE 6 면도날',
#        '가그린 레귤러', '고소한국산콩두부(부침용)(대상)', '까스명수(단품)', '깨끗한나라 키친타올',
#        '뉴트로지나 Ultra Sheer Dry-Touch Sun Block', '뉴트로지나릴렉싱바디워시',
#        '니베아 Face Sun Block Moisturizing Cream', '니베아 Fresh Sun Lotion',
#        '다우니 고농축 블루튤립과 달콤한 라일락', '닥터 아토마일드(묶음)', '달콤한 베지밀 비', '달콤한 삼육두유 B',
#        '대림게맛살큰잔치', '대림선어묵 부산어묵', '대상 사과식초', '대한웰빙호일 15m*25m',
#        '델몬트 스카시플러스 100', '도브 뷰티 너리싱 바디워시', '도브 센스티브스킨 바디워시 ', '동원 꽁치',
#        '동원복숭아(황도) 슬라이스', '동원양반포기김치(2.2kg)', '동원참치 라이트스탠다드(묶음)',
#        '듀라셀 울트라 파워체크 AA*2입(피엔지)', '듀라셀 울트라 파워체크 AAA*2입', '디럭스키친타올',
#        '떠먹는불가리스 딸기 오리지날(4개묶음)', '레쓰비 마일드(175ml)', '롯데비앤나(400g)',
#        '롯데슬라이스햄', '롯데호일(25cm x 30m)', '롯데호일(30cm x 30m) ', '리스테린 쿨민트',
#        '마하3 면도날', '맑고신선한옥수수유', '맛있는 미역국', '매일 카페라떼 마일드',
#        '매일우유 오리지널(ESL)(1000ml)', '매일유업 뼈로가는 칼슘치즈(180g)',
#        '매일유업 뼈로가는 칼슘치즈(270g)', '맥심모카골드', '메로나(단품)', '모닝버터(해바라기유)(200g)',
#        '무가염버터(450g)', '무균무때(욕실용)', '미닛메이드 오리지날 오렌지 100',
#        '미장센 펄샤이닝모이스쳐 린스', '미장센 펄샤이닝모이스쳐 샴푸', '백설 중력밀가루(1kg)', '백설국내콩기름',
#        '백설꽃소금', '백설부침가루(1kg)', '벡셀AA*2입', '비타500(묶음)', '비타파워',
#        '비트 O2 살균표백제', '뼈로가는 칼슘두유 담백한맛', '뽑아쓰는 크린백', '사누끼 가쓰오 생우동',
#        '사조 꽁치', '삼다수(2L)', '삼다수(500ml)', '새콤달콤 간편한 유부초밥 박사(160g*2)',
#        '샘표 김치찌개용 꽁치', '샘표황도', '샤프란 코튼 앤 크림', '서울우유 체다슬라이스치즈(200g)',
#        '서울우유 체다슬라이스치즈(400g)', '세이프 유기농 발아현미 리필', '스타벅스 커피라떼',
#        '스페셜K 오리지널(480g)', '싱싱맛살', '썬 부탄가스', '아비노베이비데일리모이스춰로션', '아이비',
#        '아이시스(2L)', '아이시스(500ml)', '악마의유혹 프렌치 카페오레', '알뜨랑비누 핑크', '알프스가스',
#        '양반 구운 김밥김', '엘라스틴 맥시마이징 볼륨 샴푸', '엘라스틴 맥시마이징 볼륨 컨디셔너', '옛날당면',
#        '오뚜기 꽁치', '오뚜기황도', '오리지널 요플레(4개묶음)', '옥수수 마가린(200g)', '옥수수수염차',
#        '올에이 중형 고무장갑', '위청수(단품)', '의성 마늘 프랑크(350g)', '이오 20s (3개묶음)',
#        '자연의 시작 불가리스 사과 (4개묶음)', '자연퐁 솔잎향 세균설거지(용기)', '잘풀리는집 보습미용티슈',
#        '지퍼락 지퍼백(중)', '참작 참잘만든 슬라이스햄', '청정원 우리쌀 크림스프', '칩포테이토 오리지날',
#        '켈로그 콘푸로스트(600g)', '쿠킹호일(25cm x 30m)(삼아)', '큐원 영양강화밀가루(1kg)',
#        '크린랩(22cm x 50m)', '크린랩(30cm x 50m)', '크린랩_고무장갑(중) (묶음)', '크린백',
#        '크린지퍼백', '팬틴 바운시 볼륨케어 컨디셔닝 린스', '페브리즈 깨끗한 무향(370)',
#        '페브리즈 깨끗한 무향(900)', '페이스선블럭 화이트닝', '포스트 콘푸라이트(600g)', '푸드림 하얀설탕',
#        '풀무원 새콤달콤 유부(330g)', '퓨어가닉허브로션', '프레시안 주부초밥왕(320g)', '프레시안삼호부산어묵',
#        '프렌치까페믹스', '프리미엄 산양분유 1단계(800g)', '하선정 숯 김밥단무지', '하이드로5 면도날',
#        '해태아이스쿨', '해피바스 내추럴24핸드크림', '해피바스 로즈에센스 로맨틱 바디워시',
#        '해피바스 항균 레몬그라스 핸드워시', '햇바삭김 김밥김', '홈스타 곰팡이 싹', '홈스타 제습과 방충을 한번에',
#        '후레쉬랩(25cm x 50m)(3M)'], dtype=object)

# %%
df.loc['롯데슈퍼']
# Out:
#       Unnamed: 0        조사일          생필품           식품
# 브랜드
# 롯데슈퍼           6 2014-01-01  7368.502604  5044.442488
# 롯데슈퍼           6 2014-02-01  7875.481771  5082.359155
# 롯데슈퍼           6 2014-03-01  7726.619718  5035.344178
# 롯데슈퍼           6 2014-04-01  7612.622354  5007.914152
# 롯데슈퍼           6 2014-05-01  7838.843085  5034.685299
# ...          ...        ...          ...          ...
# 롯데슈퍼           6 2021-08-01  6989.750031  5458.684545
# 롯데슈퍼           6 2021-09-01  7135.716497  4952.127864
# 롯데슈퍼           6 2021-10-01  7155.329449  4828.741685
# 롯데슈퍼           6 2021-11-01  5883.570243  4420.351037
# 롯데슈퍼           6 2021-12-01  6003.769356  4383.676758
#
# [95 rows x 4 columns]

# %%
def find_brand(x):
    global brands
    for bra in brands:
        if bra in x:
            return bra
    return np.nan

def categorization(x):
    global li_meat
    global li_groceries
    global li_necessaries
    global else_li
    if x == '무':
        return '식품'
    for meat in li_meat:
        if meat in x:
            return '축산물'
    for gro in li_groceries:
        if gro in x:
            return '식품'
    for nec in li_necessaries:
        if nec in x:
            return '생필품'
    return np.nan

def find_prod(x):
    global all_pro
    if x in all_pro:
        return x
    return np.nan

# %%
# df.drop('제조사', axis = 1, inplace=True)
# df.drop('세일여부', axis = 1, inplace=True)
# df.drop('1+1', axis = 1, inplace=True)
df['브랜드'] = df['판매업소'].apply(find_brand)
df['상품명'] = df['상품명'].apply(find_prod)
# df.dropna(how = 'any', inplace = True)
df['상품명'] = df.상품명.astype('category')
df['브랜드'] = df.브랜드.astype('category')
df['분류'] = df.상품명.apply(categorization)
df['분류'] = df.분류.astype('category')
df['조사일'] = '{}-{}'.format(year,month)

# %%
df
# Out:
#        상품명      조사일  판매가격      판매업소      제조사 세일여부 1+1    브랜드  분류
# 0      NaN  2021-12  6600    이마트양산점     서울우유    N   N    이마트 NaN
# 1      NaN  2021-12  2500    이마트양산점    농협목우촌    N   N    이마트 NaN
# 2      NaN  2021-12  1630    이마트양산점      오뚜기    N   N    이마트 NaN
# 3      NaN  2021-12  3500    이마트양산점   CJ제일제당    N   N    이마트 NaN
# 4      NaN  2021-12  4100    이마트양산점   CJ제일제당    N   N    이마트 NaN
# ...     ..      ...   ...       ...      ...  ...  ..    ...  ..
# 120441 NaN  2021-12  4300  현대백화점충청점      풀무원    N   N  현대백화점 NaN
# 120442 NaN  2021-12  6900  현대백화점충청점     매일유업    N   N  현대백화점 NaN
# 120443 NaN  2021-12  2650  현대백화점충청점      오뚜기    N   N  현대백화점 NaN
# 120444 NaN  2021-12  6050  현대백화점충청점       샘표    N   N  현대백화점 NaN
# 120445 NaN  2021-12  5500  현대백화점충청점  유니레버코리아    N   N  현대백화점 NaN
#
# [120446 rows x 9 columns]

# %%
# 2014년부터 빠지지 않고 등장하는 상품
df_2014_1 = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터/2014년 1월 가격데이터.csv'.format(year,month), encoding='ansi')
all_pro = df_2014_1.상품명.unique()
for year in range(2014, 2022):
    for month in range(1,13):
        df = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터/{}년 {}월 가격데이터.csv'.format(year,month), encoding='ansi')
        all_pro = np.intersect1d(all_pro, df.상품명.unique())
        print(year, end = ' ')
    print()
print('end')
# Out:
# 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014
# 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015
# 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016
# 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017
# 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018
# 2019 2019 2019 2019 2019 2019 2019 2019 2019 2019 2019 2019
# 2020 2020 2020 2020 2020 2020 2020 2020 2020 2020 2020 2020
# 2021 2021 2021 2021 2021 2021 2021 2021 2021 2021 2021 2021
# end

# %%
# 데이터 전처리
for year in range(2014, 2022):
    for month in range(1,13):
        df = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터/{}년 {}월 가격데이터.csv'.format(year,month), encoding='ansi')
        try:
            df.drop('제조사', axis = 1, inplace=True)
        except:
            pass
        try:
            df.drop('세일여부', axis = 1, inplace=True)
        except:
            pass
        try:
            df.drop('원 플러스 원', axis = 1, inplace=True)
        except:
            pass
        try:
            df.drop('1+1', axis = 1, inplace=True)
        except:
            pass
        df['브랜드'] = df['판매업소'].apply(find_brand)
        df['상품명'] = df['상품명'].apply(find_prod)
        df.dropna(how = 'any', inplace = True)
        df['상품명'] = df.상품명.astype('category')
        df['브랜드'] = df.브랜드.astype('category')
        df['분류'] = df.상품명.apply(categorization)
        df['분류'] = df.분류.astype('category')
        df['조사일'] = '{}-{}'.format(year,month)
# #         df['조사일'] = pd.to_datetime(df.조사일)
# #        df.set_index('브랜드', inplace = True)
#         grouped = df.groupby(['조사일','브랜드','분류']).판매가격.mean()
#         temp = grouped.unstack().reset_index()
#         temp.to_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/{}년{}월 평균.csv'.format(year,month), encoding='ansi') 
        df.to_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/{}년{}월 데이터.csv'.format(year,month), encoding='ansi')
        print(year, end = ' ')
    print()
print('end')
# Out:
# 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014
# 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015
# 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10648/4022706437.py in <module>
#       5 for year in range(2014, 2022):
#       6     for month in range(1,13):
# ----> 7         df = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터/{}년 {}월 가격데이터.csv'.format(year,month), encoding='ansi')
#       8         try:
#       9             df.drop('제조사', axis = 1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
df_2014_1 = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/2014년1월 데이터.csv', encoding='ansi')
df_2014_1
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 상품명, 조사일, 판매가격, 판매업소, 브랜드, 분류]
# Index: []

# %%
# 각 브랜드 별 유지되는 상품 리스트
# 각 브랜드 별 상품
df_2014_1 = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/2014년1월 데이터.csv', encoding='ansi')
prod_bra = df_2014_1.groupby('브랜드')['상품명'].unique()
for year in range(2014, 2022):
    for month in range(1,13):
        df = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/{}년{}월 데이터.csv'.format(year,month), encoding='ansi')
        for bra in brands:
            try:
                prod_bra[bra] = np.intersect1d(prod_bra[bra], df.groupby('브랜드')['상품명'].unique()[bra])
            except:
                continue
        print(year, end = ' ')
    print()
print('end')
# Out:
# 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014
# 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015
# 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016
# 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017
# 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018
# 2019 2019 2019 2019 2019 2019 2019 2019 2019 2019 2019 2019
# 2020 2020 2020 2020 2020 2020 2020 2020 2020 2020 2020 2020
# 2021 2021 2021 2021 2021 2021 2021 2021 2021 2021 2021 2021
# end

# %%
df_2014_1
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 상품명, 조사일, 판매가격, 판매업소, 브랜드, 분류]
# Index: []

# %%
df_merge= pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/2014년1월 데이터.csv', encoding='ansi')
for bra in brands:
    try:
        df_merge.loc[bra] = df_merge.loc[bra]['상품명'].apply(lambda x: x if x in prod_li[bra] else np.nan)
    except:
        continue
df_merge = df_merge.loc[bra]['CU'].apply(lambda x: x if x in prod_li['CU'] else np.nan)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '농협'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10648/3797884516.py in <module>
#       5     except:
#       6         continue
# ----> 7 df_merge = df_merge.loc[bra]['CU'].apply(lambda x: x if x in prod_li['CU'] else np.nan)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: '농협'

# %%
# 각 브랜드 별 유지되는 상품이 아니면 nan값으로
df_merge= pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/2014년1월 데이터.csv', encoding='ansi')
for bra in brands:
    try:
        df_merge = df_merge.loc[bra]['상품명'].apply(lambda x: x if x in prod_li[bra] else np.nan)
    except:
        continue
for year in range(2014, 2015):
    for month in range(1,13):
        if year == 2014 and month == 1:
            continue
        df = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/{}년{}월 데이터.csv'.format(year,month), encoding='ansi')
        df.drop('Unnamed: 0', axis = 1, inplace = True)
        df['조사일'] = pd.to_datetime(df.조사일)
        df = df_2014_1.sort_values('조사일')
        df = df_2014_1.fillna(method='ffill')
        df.set_index('브랜드', inplace = True)
        df = df.sort_values('상품명')
        for bra in brands:
            try:
                df = df.loc[bra]['상품명'].apply(lambda x: x if x in prod_li[bra] else np.nan)
                df_merge = df_merge.append(df)
            except:
                continue
#         print(df.loc['세븐일레븐'].상품명.nunique())
#         df.to_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/{}년{}월 데이터-1.csv'.format(year,month), encoding='ansi')
        print(year, end = ' ')
    print()
df.merge.to_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/{}년{}월 데이터-merge.csv'.format(year,month), encoding='ansi') 
print('end')
# Out:
# 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014
# end

# %%
# df 합치기
df_merge = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/2014년1월 데이터-1.csv', encoding='ansi')
for year in range(2014, 2015):
    for month in range(1,13):
        if year == 2014 and month == 1:
            continue
        temp = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/{}년{}월 데이터-1.csv'.format(year,month),encoding = 'ansi')
        
        df_merge = df_merge.append(temp)

# %%
df_merge
# Out:
#          브랜드  Unnamed: 0                  상품명     조사일   판매가격      판매업소   분류
# 0        이마트           0  서울우유 체다슬라이스치즈(400g)  2014-1   6600    이마트양산점   식품
# 1        이마트           1               식빵위의네모  2014-1   2500    이마트양산점   식품
# 2        이마트           2                오뚜기황도  2014-1   1630    이마트양산점   식품
# 3        이마트           3          해찬들 재래식 된장   2014-1   3500    이마트양산점   식품
# 4        이마트           4              백설국내콩기름  2014-1   4100    이마트양산점   식품
# ...      ...         ...                  ...     ...    ...       ...  ...
# 59082  롯데백화점       64203   클링스 어드밴스드 클린민트(묶음)  2014-1   7900  롯데백화점노원점  생필품
# 59083  롯데백화점       64204      쉐리 후레쉬 시트 카밍라벤더  2014-1   7900  롯데백화점노원점  생필품
# 59084  롯데백화점       64205           물먹는 하마 옷장용  2014-1   6500  롯데백화점노원점  생필품
# 59085  롯데백화점       64206              프렌치까페믹스  2014-1  25700  롯데백화점노원점   식품
# 59086  롯데백화점       64207     도브 데미지 볼륨 부스트 샴푸  2014-1  11200  롯데백화점노원점  생필품
#
# [59087 rows x 7 columns]

# %%
df_merge.loc['롯데마트']['상품명']
# Out:
# 브랜드
# 롯데마트               1964 정통 크림빵
# 롯데마트               1964 정통 크림빵
# 롯데마트               1964 정통 크림빵
# 롯데마트               1964 정통 크림빵
# 롯데마트               1964 정통 크림빵
#                  ...
# 롯데마트                 국산아작아작콩나물
# 롯데마트          웰빙 다시다 산들애 국내산해물
# 롯데마트                      참크래커
# 롯데마트                 마일드참치(묶음)
# 롯데마트    매일우유 오리지널(ESL)(1000ml)
# Name: 상품명, Length: 270552, dtype: object

# %%
prod_li['이마트']
# Out:
# array(['대한웰빙호일 15m*25m', '맑고신선한옥수수유', '맥심모카골드', '무가염버터(450g)',
#        '비타500(묶음)', '샘표 김치찌개용 꽁치', '썬 부탄가스', '알프스가스', '오뚜기황도',
#        '오리지널 요플레(4개묶음)', '켈로그 콘푸로스트(600g)', '풀무원 새콤달콤 유부(330g)'],
#       dtype=object)

# %%
df_merge.loc['이마트']['상품명'].apply(lambda x: x if x in prod_li[bra] else np.nan)
# Out:
# 브랜드
# 이마트    서울우유 체다슬라이스치즈(400g)
# 이마트                    NaN
# 이마트                  오뚜기황도
# 이마트                    NaN
# 이마트                백설국내콩기름
#               ...
# 이마트                    NaN
# 이마트          백설 중력밀가루(1kg)
# 이마트              맑고신선한옥수수유
# 이마트              비타500(묶음)
# 이마트                    NaN
# Name: 상품명, Length: 215112, dtype: object

# %%
df_merge.loc['이마트']['상품명']
# Out:
# 브랜드
# 이마트    서울우유 체다슬라이스치즈(400g)
# 이마트                 식빵위의네모
# 이마트                  오뚜기황도
# 이마트            해찬들 재래식 된장
# 이마트                백설국내콩기름
#               ...
# 이마트           진라면(순한맛) 5개입
# 이마트          백설 중력밀가루(1kg)
# 이마트              맑고신선한옥수수유
# 이마트              비타500(묶음)
# 이마트    생야채돼지고기물만두(400g*2봉)
# Name: 상품명, Length: 215112, dtype: object

# %%
df_2014_1 = pd.read_csv(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\저장/2014년1월 데이터-1.csv', encoding='ansi')

# %%
df_2014_1
# Out:
#           브랜드  Unnamed: 0                   상품명     조사일  판매가격       판매업소   분류
# 0      신세계백화점       36126           1964 정통 크림빵  2014-1  3150  신세계백화점죽전점   식품
# 1        롯데마트       49018           1964 정통 크림빵  2014-1  1960    롯데마트수완점   식품
# 2        롯데슈퍼       48916           1964 정통 크림빵  2014-1  1960    롯데슈퍼연수점   식품
# 3        롯데마트       26395           1964 정통 크림빵  2014-1  1540    롯데마트포항점   식품
# 4        롯데마트       26462           1964 정통 크림빵  2014-1  1540  롯데마트 청량리점   식품
# ...       ...         ...                   ...     ...   ...        ...  ...
# 59082    홈플러스       18319  후레쉬랩(25cm x 50m)(3M)  2014-1  3410  홈플러스 동대문점  생필품
# 59083   현대백화점         730  후레쉬랩(25cm x 50m)(3M)  2014-1  3800   현대백화점중동점  생필품
# 59084    홈플러스       18009  후레쉬랩(25cm x 50m)(3M)  2014-1  3410    홈플러스금천점  생필품
# 59085    롯데마트         220  후레쉬랩(25cm x 50m)(3M)  2014-1  3410    롯데마트구로점  생필품
# 59086    롯데마트       36245  후레쉬랩(25cm x 50m)(3M)  2014-1  3410    롯데마트구리점  생필품
#
# [59087 rows x 7 columns]

# %%
# df_2014_1.drop('Unnamed: 0', axis = 1, inplace = True)
df_2014_1['조사일'] = pd.to_datetime(df_2014_1.조사일)
df_2014_1 = df_2014_1.sort_values('조사일')
df_2014_1 = df_2014_1.fillna(method='ffill')
# df_2014_1.set_index('브랜드', inplace = True)
df_2014_1
# Out:
#                         상품명        조사일   판매가격      판매업소   분류
# 브랜드
# 이마트     서울우유 체다슬라이스치즈(400g) 2014-01-01   6600    이마트양산점   식품
# 농협     미쟝센 쉽고빠른거품염색(3N 흑갈색) 2014-01-01  15000   농협유통고양점  생필품
# 농협          국산콩두부(찌개용)(풀무원) 2014-01-01   3600   농협유통고양점   식품
# 이마트                  식빵위의네모 2014-01-01   2500    이마트양산점   식품
# 이마트                   오뚜기황도 2014-01-01   1630    이마트양산점   식품
# ...                     ...        ...    ...       ...  ...
# 현대백화점              대림게맛살큰잔치 2014-01-01   3180  현대백화점충청점   식품
# 현대백화점             카스 프레쉬 6캔 2014-01-01   8100  현대백화점충청점   식품
# 현대백화점               목초란 10구 2014-01-01   4300  현대백화점충청점  축산물
# 현대백화점               대상 사과식초 2014-01-01   2100  현대백화점충청점   식품
# 현대백화점                도브 뷰티바 2014-01-01   5500  현대백화점충청점  생필품
#
# [110780 rows x 5 columns]

# %%
df_2014_1.loc['CU']['상품명'].apply(lambda x: x if x in prod_li['CU'] else np.nan)
df_2014_1
# Out:
#           브랜드  Unnamed: 0                   상품명     조사일  판매가격       판매업소   분류
# 0      신세계백화점       36126           1964 정통 크림빵  2014-1  3150  신세계백화점죽전점   식품
# 1        롯데마트       49018           1964 정통 크림빵  2014-1  1960    롯데마트수완점   식품
# 2        롯데슈퍼       48916           1964 정통 크림빵  2014-1  1960    롯데슈퍼연수점   식품
# 3        롯데마트       26395           1964 정통 크림빵  2014-1  1540    롯데마트포항점   식품
# 4        롯데마트       26462           1964 정통 크림빵  2014-1  1540  롯데마트 청량리점   식품
# ...       ...         ...                   ...     ...   ...        ...  ...
# 59082    홈플러스       18319  후레쉬랩(25cm x 50m)(3M)  2014-1  3410  홈플러스 동대문점  생필품
# 59083   현대백화점         730  후레쉬랩(25cm x 50m)(3M)  2014-1  3800   현대백화점중동점  생필품
# 59084    홈플러스       18009  후레쉬랩(25cm x 50m)(3M)  2014-1  3410    홈플러스금천점  생필품
# 59085    롯데마트         220  후레쉬랩(25cm x 50m)(3M)  2014-1  3410    롯데마트구로점  생필품
# 59086    롯데마트       36245  후레쉬랩(25cm x 50m)(3M)  2014-1  3410    롯데마트구리점  생필품
#
# [59087 rows x 7 columns]

# %%
df.apply(lambda x:np.square(x) if x.name in ['A','B'] else x)

# %%
def brand_prod(br, x):
    global prod_li
    global brands
    if x not in prod_li[br]:
        return np.nan

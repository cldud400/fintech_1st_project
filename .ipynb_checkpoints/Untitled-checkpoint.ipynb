# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import MySQLdb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests
from bs4 import BeautifulSoup

import re

# %%
# matplotlib 한글화

import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus'] = False

path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

# %%
price_per = pd.read_excel(r'C:\Users\bitcamp\Desktop\2022년 1월 가격데이터\동향/생필품상품별_동향2014년.xls')

price_per.head()
# Out:
#    번호            상품명  대분류명   중분류명  소분류명    제조사명   총용량 총용량명  단위용량 단위용량명  ...  \
# 0   1    샘표소면(1.1kg)  가공식품  곡물가공품    국수      샘표  1100    g   100     g  ...
# 1   2  옛날국수 소면(900g)  가공식품  곡물가공품    국수     오뚜기   900    g   100     g  ...
# 2   3       제일제면소 소면  가공식품  곡물가공품    국수  CJ제일제당   500    g   100     g  ...
# 3   4          찰국수소면  가공식품  곡물가공품    국수  CJ제일제당   900    g   100     g  ...
# 4   5        개성 감자만두  가공식품  곡물가공품  냉동만두      동원   600    g   100     g  ...
#
#      2014-03    2014-04    2014-05    2014-06    2014-07    2014-08  \
# 0   3427/311   3450/314   3468/315   3486/317   3514/319   3371/306
# 1   2614/291   2508/279   2573/286   2378/264   2248/250   2286/254
# 2   2111/422   1975/395   1918/384   1866/373   1770/354   1885/377
# 3   2425/270   2425/270   2426/270   2425/270   2425/270   2427/270
# 4  6740/1123  6942/1157  6599/1100  6731/1122  6644/1108  6878/1146
#
#      2014-09    2014-10    2014-11    2014-12
# 0   2820/256   3450/313   3658/332   3386/308
# ...

# %%
price_per.drop('중분류명', axis=1, inplace = True)

# %%
price_per.drop('소분류명', axis=1, inplace = True)

# %%
price_per.drop('제조사명', axis=1, inplace = True)
price_per.drop('총용량', axis=1, inplace = True)
price_per.drop('총용량명', axis=1, inplace = True)
price_per.drop('단위용량명', axis=1, inplace = True)
price_per.drop('단위용량', axis=1, inplace = True)

# %%
price_per = price_per.set_index('상품명')

# %%
price_per.drop('번호', axis=1, inplace = True)

# %%
price_per
# Out:
#                      대분류명    2014-01    2014-02    2014-03    2014-04  \
# 상품명
# 샘표소면(1.1kg)          가공식품   3479/316   3478/316   3427/311   3450/314
# 옛날국수 소면(900g)        가공식품   2542/283   2609/290   2614/291   2508/279
# 제일제면소 소면             가공식품   2095/419   2098/420   2111/422   1975/395
# 찰국수소면                가공식품   2429/270   2425/270   2425/270   2425/270
# 개성 감자만두              가공식품  6627/1105  6838/1140  6740/1123  6942/1157
# ...                   ...        ...        ...        ...        ...
# 돼지고기 삼겹살(100g)       신선식품  1622/1622  1617/1617  2080/2080  2012/2012
# 쇠고기 등심(1+등급, 100g)   신선식품  8386/8386  8167/8167  8260/8260  8491/8491
# 쇠고기 등심(1등급, 100g)    신선식품  7147/7147  6940/6940  6947/6947  6835/6835
# 쇠고기 불고기(1+등급, 100g)  신선식품  3639/3639  3646/3646  3721/3721  3810/3810
# 쇠고기 불고기(1등급, 100g)   신선식품  3387/3387  3395/3395  3431/3431  3518/3518
#
#                        2014-05    2014-06    2014-07    2014-08    2014-09  \
# 상품명
# ...
